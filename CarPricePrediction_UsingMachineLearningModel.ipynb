# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Lakshmeesh s reddy\Desktop\Dinku\JOB\ML-project\data car.csv")

# %%
df.head(5)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
df.head(5)
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# ...

# %%
strings = list(df.dtypes[df.dtypes == 'object'].index)

# %%
strings
# Out:
# ['make',
#  'model',
#  'engine_fuel_type',
#  'transmission_type',
#  'driven_wheels',
#  'market_category',
#  'vehicle_size',
#  'vehicle_style']

# %%
for col in strings:
    df[col] = df[col].str.lower().str.replace(' ', '_')

# %%
High_yr = df['year'].max()
High_yr
# Out:
# 2017

# %%
df['age'] =  (High_yr + 1) - df.year

# %%
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4  bmw    1_series  2011  premium_unleaded_(required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            manual  rear_wheel_drive              2.0
# 1               6.0            manual  rear_wheel_drive              2.0
# 2               6.0            manual  rear_wheel_drive              2.0
# 3               6.0            manual  rear_wheel_drive              2.0
# 4               6.0            manual  rear_wheel_drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# ...

# %%
df['number_of_doors'] = df['number_of_doors'].astype('object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   make               11914 non-null  object
#  1   model              11914 non-null  object
#  2   year               11914 non-null  int64
#  3   engine_fuel_type   11911 non-null  object
#  4   engine_hp          11845 non-null  float64
#  5   engine_cylinders   11884 non-null  float64
#  6   transmission_type  11914 non-null  object
#  7   driven_wheels      11914 non-null  object
#  8   number_of_doors    11908 non-null  object
#  9   market_category    8172 non-null   object
#  10  vehicle_size       11914 non-null  object
#  11  vehicle_style      11914 non-null  object
#  12  highway_mpg        11914 non-null  int64
#  13  city_mpg           11914 non-null  int64
#  14  popularity         11914 non-null  int64
#  15  msrp               11914 non-null  int64
# ...

# %%
df[df['engine_fuel_type'].isna()]
# Out:
#          make   model  year engine_fuel_type  engine_hp  engine_cylinders  \
# 11321  suzuki  verona  2004              NaN      155.0               6.0
# 11322  suzuki  verona  2004              NaN      155.0               6.0
# 11323  suzuki  verona  2004              NaN      155.0               6.0
#
#       transmission_type      driven_wheels number_of_doors market_category  \
# 11321         automatic  front_wheel_drive             4.0             NaN
# 11322         automatic  front_wheel_drive             4.0             NaN
# 11323         automatic  front_wheel_drive             4.0             NaN
#
#       vehicle_size vehicle_style  highway_mpg  city_mpg  popularity   msrp  \
# 11321      midsize         sedan           25        17         481  17199
# 11322      midsize         sedan           25        17         481  20199
# 11323      midsize         sedan           25        17         481  18499
#
#        age
# 11321   14
# 11322   14
# 11323   14

# %%
df[df['make'].isin(['suzuki'])].engine_fuel_type.unique()
# Out:
# array(['regular_unleaded', nan], dtype=object)

# %%
df[df['model'] == 'verona']
# Out:
#          make   model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 11321  suzuki  verona  2004               NaN      155.0               6.0
# 11322  suzuki  verona  2004               NaN      155.0               6.0
# 11323  suzuki  verona  2004               NaN      155.0               6.0
# 11324  suzuki  verona  2005  regular_unleaded      155.0               6.0
# 11325  suzuki  verona  2005  regular_unleaded      155.0               6.0
# 11326  suzuki  verona  2005  regular_unleaded      155.0               6.0
# 11327  suzuki  verona  2005  regular_unleaded      155.0               6.0
# 11328  suzuki  verona  2006  regular_unleaded      155.0               6.0
# 11329  suzuki  verona  2006  regular_unleaded      155.0               6.0
#
#       transmission_type      driven_wheels number_of_doors market_category  \
# 11321         automatic  front_wheel_drive             4.0             NaN
# ...

# %%
df['engine_fuel_type'] = df['engine_fuel_type'].replace(np.nan, 'regular_unleaded')

# %%
df['engine_fuel_type'].isna().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   make               11914 non-null  object
#  1   model              11914 non-null  object
#  2   year               11914 non-null  int64
#  3   engine_fuel_type   11914 non-null  object
#  4   engine_hp          11845 non-null  float64
#  5   engine_cylinders   11884 non-null  float64
#  6   transmission_type  11914 non-null  object
#  7   driven_wheels      11914 non-null  object
#  8   number_of_doors    11908 non-null  object
#  9   market_category    8172 non-null   object
#  10  vehicle_size       11914 non-null  object
#  11  vehicle_style      11914 non-null  object
#  12  highway_mpg        11914 non-null  int64
#  13  city_mpg           11914 non-null  int64
#  14  popularity         11914 non-null  int64
#  15  msrp               11914 non-null  int64
# ...

# %%
df[df['engine_hp'].isna()]
# Out:
#          make        model  year                engine_fuel_type  engine_hp  \
# 539      fiat         500e  2015                        electric        NaN
# 540      fiat         500e  2016                        electric        NaN
# 541      fiat         500e  2017                        electric        NaN
# 2905  lincoln  continental  2017  premium_unleaded_(recommended)        NaN
# 2906  lincoln  continental  2017  premium_unleaded_(recommended)        NaN
# ...       ...          ...   ...                             ...        ...
# 9850      kia      soul_ev  2015                        electric        NaN
# 9851      kia      soul_ev  2015                        electric        NaN
# 9852      kia      soul_ev  2016                        electric        NaN
# 9853      kia      soul_ev  2016                        electric        NaN
# 9854      kia      soul_ev  2016                        electric        NaN
#
# ...

# %%
df[(df.engine_fuel_type == 'electric') & (df.make == 'fiat')]
# Out:
#      make model  year engine_fuel_type  engine_hp  engine_cylinders  \
# 539  fiat  500e  2015         electric        NaN               0.0
# 540  fiat  500e  2016         electric        NaN               0.0
# 541  fiat  500e  2017         electric        NaN               0.0
#
#     transmission_type      driven_wheels number_of_doors market_category  \
# 539      direct_drive  front_wheel_drive             2.0       hatchback
# 540      direct_drive  front_wheel_drive             2.0       hatchback
# 541      direct_drive  front_wheel_drive             2.0       hatchback
#
#     vehicle_size  vehicle_style  highway_mpg  city_mpg  popularity   msrp  age
# 539      compact  2dr_hatchback          108       122         819  31800    3
# 540      compact  2dr_hatchback          103       121         819  31800    2
# 541      compact  2dr_hatchback          103       121         819  31800    1

# %%
re = df['make'] == 'fiat'
mean_fiat = df[df.make == 'fiat']['engine_hp'].mean()
df.loc[re, 'engine_hp'] =  df.loc[re, 'engine_hp'].fillna(mean_fiat)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   make               11914 non-null  object
#  1   model              11914 non-null  object
#  2   year               11914 non-null  int64
#  3   engine_fuel_type   11914 non-null  object
#  4   engine_hp          11848 non-null  float64
#  5   engine_cylinders   11884 non-null  float64
#  6   transmission_type  11914 non-null  object
#  7   driven_wheels      11914 non-null  object
#  8   number_of_doors    11908 non-null  object
#  9   market_category    8172 non-null   object
#  10  vehicle_size       11914 non-null  object
#  11  vehicle_style      11914 non-null  object
#  12  highway_mpg        11914 non-null  int64
#  13  city_mpg           11914 non-null  int64
#  14  popularity         11914 non-null  int64
#  15  msrp               11914 non-null  int64
# ...

# %%
df[df['engine_hp'].isna()]
# Out:
#          make        model  year                engine_fuel_type  engine_hp  \
# 2905  lincoln  continental  2017  premium_unleaded_(recommended)        NaN
# 2906  lincoln  continental  2017  premium_unleaded_(recommended)        NaN
# 2907  lincoln  continental  2017  premium_unleaded_(recommended)        NaN
# 2908  lincoln  continental  2017  premium_unleaded_(recommended)        NaN
# 4203     ford       escape  2017                regular_unleaded        NaN
# ...       ...          ...   ...                             ...        ...
# 9850      kia      soul_ev  2015                        electric        NaN
# 9851      kia      soul_ev  2015                        electric        NaN
# 9852      kia      soul_ev  2016                        electric        NaN
# 9853      kia      soul_ev  2016                        electric        NaN
# 9854      kia      soul_ev  2016                        electric        NaN
#
# ...

# %%
mean_1 = df[(df.make == 'lincoln') & (df.model == 'continental')]['engine_hp'].mean()

m = (df.make == 'lincoln') & (df.model == 'continental')

df.loc[m,'engine_hp'] =  df.loc[m,'engine_hp'].fillna(mean_1)

# %%
df[(df.make == 'lincoln') & (df.model == 'continental')]
# Out:
#          make        model  year                engine_fuel_type   engine_hp  \
# 2897  lincoln  continental  2001                regular_unleaded  275.000000
# 2898  lincoln  continental  2002     premium_unleaded_(required)  275.000000
# 2899  lincoln  continental  2002     premium_unleaded_(required)  275.000000
# 2900  lincoln  continental  2002     premium_unleaded_(required)  275.000000
# 2901  lincoln  continental  2002     premium_unleaded_(required)  275.000000
# 2902  lincoln  continental  2017                regular_unleaded  305.000000
# 2903  lincoln  continental  2017                regular_unleaded  305.000000
# 2904  lincoln  continental  2017                regular_unleaded  305.000000
# 2905  lincoln  continental  2017  premium_unleaded_(recommended)  288.333333
# 2906  lincoln  continental  2017  premium_unleaded_(recommended)  288.333333
# 2907  lincoln  continental  2017  premium_unleaded_(recommended)  288.333333
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   make               11914 non-null  object
#  1   model              11914 non-null  object
#  2   year               11914 non-null  int64
#  3   engine_fuel_type   11914 non-null  object
#  4   engine_hp          11852 non-null  float64
#  5   engine_cylinders   11884 non-null  float64
#  6   transmission_type  11914 non-null  object
#  7   driven_wheels      11914 non-null  object
#  8   number_of_doors    11908 non-null  object
#  9   market_category    8172 non-null   object
#  10  vehicle_size       11914 non-null  object
#  11  vehicle_style      11914 non-null  object
#  12  highway_mpg        11914 non-null  int64
#  13  city_mpg           11914 non-null  int64
#  14  popularity         11914 non-null  int64
#  15  msrp               11914 non-null  int64
# ...

# %%
df[df['engine_hp'].isna()]
# Out:
#        make    model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 4203   ford   escape  2017  regular_unleaded        NaN               4.0
# 4204   ford   escape  2017  regular_unleaded        NaN               4.0
# 4205   ford   escape  2017  regular_unleaded        NaN               4.0
# 4206   ford   escape  2017  regular_unleaded        NaN               4.0
# 4705  honda   fit_ev  2013          electric        NaN               0.0
# ...     ...      ...   ...               ...        ...               ...
# 9850    kia  soul_ev  2015          electric        NaN               0.0
# 9851    kia  soul_ev  2015          electric        NaN               0.0
# 9852    kia  soul_ev  2016          electric        NaN               0.0
# 9853    kia  soul_ev  2016          electric        NaN               0.0
# 9854    kia  soul_ev  2016          electric        NaN               0.0
#
#      transmission_type      driven_wheels number_of_doors market_category  \
# ...

# %%
ford_na_models = list(df[(df.make == 'ford') & (df['engine_hp'].isnull())]['model'].unique())
ford_na_models
# Out:
# ['escape', 'focus', 'freestar']

# %%
df[df['model'].isin(ford_na_models)]
# Out:
#       make     model  year                engine_fuel_type  engine_hp  \
# 4192  ford    escape  2015  premium_unleaded_(recommended)      178.0
# 4193  ford    escape  2015  premium_unleaded_(recommended)      178.0
# 4194  ford    escape  2015  premium_unleaded_(recommended)      178.0
# 4195  ford    escape  2015                regular_unleaded      168.0
# 4196  ford    escape  2015  premium_unleaded_(recommended)      178.0
# 4197  ford    escape  2016  premium_unleaded_(recommended)      178.0
# 4198  ford    escape  2016  premium_unleaded_(recommended)      178.0
# 4199  ford    escape  2016  premium_unleaded_(recommended)      178.0
# 4200  ford    escape  2016                regular_unleaded      168.0
# 4201  ford    escape  2016  premium_unleaded_(recommended)      178.0
# 4202  ford    escape  2017                regular_unleaded      168.0
# 4203  ford    escape  2017                regular_unleaded        NaN
# ...

# %%
ford_escape_mean = df[(df.make == 'ford') & (df.model == 'escape') & (df.engine_fuel_type == 'regular_unleaded')]['engine_hp'].mean()

ford_escape_mean
# Out:
# 168.0

# %%
df[(df.make == 'ford') & (df.model == 'escape') & (df.engine_fuel_type == 'regular_unleaded')] = df[(df.make == 'ford') & (df.model == 'escape') & (df.engine_fuel_type == 'regular_unleaded')].fillna(ford_escape_mean)

df[(df.make == 'ford') & (df.model == 'escape') & (df.engine_fuel_type == 'regular_unleaded')]
# Out:
#       make   model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 4195  ford  escape  2015  regular_unleaded      168.0               4.0
# 4200  ford  escape  2016  regular_unleaded      168.0               4.0
# 4202  ford  escape  2017  regular_unleaded      168.0               4.0
# 4203  ford  escape  2017  regular_unleaded      168.0               4.0
# 4204  ford  escape  2017  regular_unleaded      168.0               4.0
# 4205  ford  escape  2017  regular_unleaded      168.0               4.0
# 4206  ford  escape  2017  regular_unleaded      168.0               4.0
#
#      transmission_type      driven_wheels number_of_doors market_category  \
# 4195         automatic  front_wheel_drive             4.0       crossover
# 4200         automatic  front_wheel_drive             4.0       crossover
# 4202         automatic  front_wheel_drive             4.0       crossover
# 4203         automatic  front_wheel_drive             4.0       crossover
# ...

# %%
df[(df.make == 'ford') & (df.model == 'focus')][['engine_hp', 'vehicle_style']]
# Out:
#       engine_hp  vehicle_style
# 4780      160.0          sedan
# 4781      160.0  4dr_hatchback
# 4782      160.0          sedan
# 4783      160.0          sedan
# 4784      160.0  4dr_hatchback
# 4785        NaN  4dr_hatchback
# 4786      160.0          sedan
# 4787      160.0  4dr_hatchback
# 4788      160.0          sedan
# 4789        NaN  4dr_hatchback
# 4790      160.0  4dr_hatchback
# 4791      160.0          sedan
# 4792      160.0  4dr_hatchback
# 4793      123.0          sedan
# 4794      160.0          sedan
# 4795      160.0  4dr_hatchback
# 4796      160.0          sedan
# 4797      160.0          sedan
# 4798        NaN  4dr_hatchback
# 4799      160.0  4dr_hatchback

# %%
ford_focus_mean = df[(df.make == 'ford') & (df.model == 'focus') & (df.vehicle_style == '4dr_hatchback')]['engine_hp'].mean()
ford_focus_mean
# Out:
# 160.0

# %%
ford_focus = (df.make == 'ford') & (df.model == 'focus') & (df.vehicle_style == '4dr_hatchback')

ford_focus
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
df.loc[ford_focus, 'engine_hp'] = df.loc[ford_focus, 'engine_hp'].fillna(ford_focus_mean)

# %%
df[(df.make == 'ford') & (df.model == 'focus')]
# Out:
#       make  model  year          engine_fuel_type  engine_hp  \
# 4780  ford  focus  2015  flex-fuel_(unleaded/e85)      160.0
# 4781  ford  focus  2015  flex-fuel_(unleaded/e85)      160.0
# 4782  ford  focus  2015  flex-fuel_(unleaded/e85)      160.0
# 4783  ford  focus  2015  flex-fuel_(unleaded/e85)      160.0
# 4784  ford  focus  2015  flex-fuel_(unleaded/e85)      160.0
# 4785  ford  focus  2015                  electric      160.0
# 4786  ford  focus  2016  flex-fuel_(unleaded/e85)      160.0
# 4787  ford  focus  2016  flex-fuel_(unleaded/e85)      160.0
# 4788  ford  focus  2016  flex-fuel_(unleaded/e85)      160.0
# 4789  ford  focus  2016                  electric      160.0
# 4790  ford  focus  2016  flex-fuel_(unleaded/e85)      160.0
# 4791  ford  focus  2016  flex-fuel_(unleaded/e85)      160.0
# 4792  ford  focus  2017  flex-fuel_(unleaded/e85)      160.0
# 4793  ford  focus  2017          regular_unleaded      123.0
# ...

# %%
ford_freestar_mean = df[(df.make == 'ford') & (df.model == 'freestar')]['engine_hp'].mean()
ford_freestar_mean
# Out:
# 199.0

# %%
ford_freestar = (df.make == 'ford') & (df.model == 'freestar')

# %%
df.loc[ford_freestar, 'engine_hp'] = df.loc[ford_freestar, 'engine_hp'].fillna(ford_freestar_mean)

# %%
df[(df.make == 'ford') & (df.model == 'freestar')]
# Out:
#       make     model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 4914  ford  freestar  2005  regular_unleaded      199.0               6.0
# 4915  ford  freestar  2005  regular_unleaded      199.0               6.0
# 4916  ford  freestar  2005  regular_unleaded      199.0               6.0
# 4917  ford  freestar  2005  regular_unleaded      199.0               6.0
# 4918  ford  freestar  2005  regular_unleaded      199.0               6.0
# 4919  ford  freestar  2005  regular_unleaded      199.0               6.0
# 4920  ford  freestar  2006  regular_unleaded      193.0               6.0
# 4921  ford  freestar  2006  regular_unleaded      201.0               6.0
# 4922  ford  freestar  2006  regular_unleaded      193.0               6.0
# 4923  ford  freestar  2006  regular_unleaded      201.0               6.0
# 4924  ford  freestar  2007  regular_unleaded      201.0               6.0
# 4925  ford  freestar  2007  regular_unleaded      201.0               6.0
# ...

# %%
df[df['engine_hp'].isnull()]['make'].unique()
# Out:
# array(['honda', 'mitsubishi', 'chevrolet', 'nissan', 'mercedes-benz',
#        'lincoln', 'tesla', 'toyota', 'kia'], dtype=object)

# %%
# df[(df.make == 'ford') & (df.model == 'freestar')]
list(df[(df.make == 'honda') & (df['engine_hp'].isnull())]['model'].unique())
# Out:
# ['fit_ev']

# %%
df[(df.make == 'honda') & (df.model == 'fit_ev')]
# Out:
#        make   model  year engine_fuel_type  engine_hp  engine_cylinders  \
# 4705  honda  fit_ev  2013         electric        NaN               0.0
# 4706  honda  fit_ev  2014         electric        NaN               0.0
#
#      transmission_type      driven_wheels number_of_doors market_category  \
# 4705      direct_drive  front_wheel_drive             4.0       hatchback
# 4706      direct_drive  front_wheel_drive             4.0       hatchback
#
#      vehicle_size  vehicle_style  highway_mpg  city_mpg  popularity   msrp  \
# 4705      compact  4dr_hatchback          105       132        2202  36625
# 4706      compact  4dr_hatchback          105       132        2202  36625
#
#       age
# 4705    5
# 4706    4

# %%
honda_fit_ev_mean = df[(df.make == 'honda') & (df.vehicle_style == '4dr_hatchback') & (df.market_category == 'hatchback')]['engine_hp'].mean()
honda_fit_ev_mean
# Out:
# 134.4

# %%
honda_fit_ev = (df.make == 'honda') & (df.model == 'fit_ev')

# %%
df.loc[honda_fit_ev, 'engine_hp'] = df.loc[honda_fit_ev, 'engine_hp'].fillna(honda_fit_ev_mean)

# %%
df[(df.make == 'honda') & (df.model == 'fit_ev')]
# Out:
#        make   model  year engine_fuel_type  engine_hp  engine_cylinders  \
# 4705  honda  fit_ev  2013         electric      134.4               0.0
# 4706  honda  fit_ev  2014         electric      134.4               0.0
#
#      transmission_type      driven_wheels number_of_doors market_category  \
# 4705      direct_drive  front_wheel_drive             4.0       hatchback
# 4706      direct_drive  front_wheel_drive             4.0       hatchback
#
#      vehicle_size  vehicle_style  highway_mpg  city_mpg  popularity   msrp  \
# 4705      compact  4dr_hatchback          105       132        2202  36625
# 4706      compact  4dr_hatchback          105       132        2202  36625
#
#       age
# 4705    5
# 4706    4

# %%
list(df[(df.make == 'mitsubishi') & (df['engine_hp'].isnull())]['model'].unique())
# Out:
# ['i-miev']

# %%
df[(df.make == 'mitsubishi') & (df.model == 'i-miev')]
# Out:
#             make   model  year engine_fuel_type  engine_hp  engine_cylinders  \
# 5778  mitsubishi  i-miev  2014         electric        NaN               NaN
# 5779  mitsubishi  i-miev  2016         electric       66.0               NaN
# 5780  mitsubishi  i-miev  2017         electric       66.0               NaN
#
#      transmission_type     driven_wheels number_of_doors market_category  \
# 5778      direct_drive  rear_wheel_drive             4.0       hatchback
# 5779      direct_drive  rear_wheel_drive             4.0       hatchback
# 5780      direct_drive  rear_wheel_drive             4.0       hatchback
#
#      vehicle_size  vehicle_style  highway_mpg  city_mpg  popularity   msrp  \
# 5778      compact  4dr_hatchback           99       126         436  22995
# 5779      compact  4dr_hatchback           99       126         436  22995
# 5780      compact  4dr_hatchback          102       121         436  22995
#
#       age
# 5778    4
# 5779    2
# 5780    1

# %%
mitsubishi_ele_mean = df[(df.make == 'mitsubishi') & (df.model == 'i-miev')]['engine_hp'].mean()
mitsubishi_ele_mean
# Out:
# 66.0

# %%
mitsubishi_enghp = (df.make == 'mitsubishi') & (df.model == 'i-miev')

# %%
df.loc[mitsubishi_enghp, 'engine_hp'] = df.loc[mitsubishi_enghp, 'engine_hp'].fillna(mitsubishi_ele_mean)
df[(df.make == 'mitsubishi') & (df.model == 'i-miev')]
# Out:
#             make   model  year engine_fuel_type  engine_hp  engine_cylinders  \
# 5778  mitsubishi  i-miev  2014         electric       66.0               NaN
# 5779  mitsubishi  i-miev  2016         electric       66.0               NaN
# 5780  mitsubishi  i-miev  2017         electric       66.0               NaN
#
#      transmission_type     driven_wheels number_of_doors market_category  \
# 5778      direct_drive  rear_wheel_drive             4.0       hatchback
# 5779      direct_drive  rear_wheel_drive             4.0       hatchback
# 5780      direct_drive  rear_wheel_drive             4.0       hatchback
#
#      vehicle_size  vehicle_style  highway_mpg  city_mpg  popularity   msrp  \
# 5778      compact  4dr_hatchback           99       126         436  22995
# 5779      compact  4dr_hatchback           99       126         436  22995
# 5780      compact  4dr_hatchback          102       121         436  22995
#
#       age
# 5778    4
# 5779    2
# 5780    1

# %% [raw]
# # list(df[(df.make == 'honda') & (df['engine_hp'].isnull())]['model'].unique())
# df[(df.make == 'honda') & (df.model == 'fit_ev')]
# honda_fit_ev = (df.make == 'honda') & (df.model == 'fit_ev')
# df.loc[honda_fit_ev, 'engine_hp'] = df.loc[honda_fit_ev, 'engine_hp'].fillna(honda_fit_ev_mean)
# df[(df.make == 'honda') & (df.model == 'fit_ev')]

# %%
df[df['engine_hp'].isnull()]['make'].unique()
# Out:
# array(['chevrolet', 'nissan', 'mercedes-benz', 'lincoln', 'tesla',
#        'toyota', 'kia'], dtype=object)

# %%
list(df[(df.make == 'chevrolet') & (df['engine_hp'].isnull())]['model'].unique())
# Out:
# ['impala']

# %%
df[(df.make == 'chevrolet') & (df.model == 'impala')]
# Out:
#            make   model  year                  engine_fuel_type  engine_hp  \
# 5823  chevrolet  impala  2015                  regular_unleaded      195.0
# 5824  chevrolet  impala  2015                  regular_unleaded      195.0
# 5825  chevrolet  impala  2015  flex-fuel_(unleaded/natural_gas)        NaN
# 5826  chevrolet  impala  2015          flex-fuel_(unleaded/e85)      305.0
# 5827  chevrolet  impala  2015          flex-fuel_(unleaded/e85)      305.0
# 5828  chevrolet  impala  2015                  regular_unleaded      195.0
# 5829  chevrolet  impala  2015                  regular_unleaded      195.0
# 5830  chevrolet  impala  2015  flex-fuel_(unleaded/natural_gas)        NaN
# 5831  chevrolet  impala  2016  flex-fuel_(unleaded/natural_gas)        NaN
# 5832  chevrolet  impala  2016          flex-fuel_(unleaded/e85)      305.0
# 5833  chevrolet  impala  2016  flex-fuel_(unleaded/natural_gas)        NaN
# ...

# %%
chevrolet_eng_hp_mean = df[(df.make == 'chevrolet') & (df.model == 'impala')]['engine_hp'].mean()
chevrolet_eng_hp_mean
# Out:
# 240.83333333333334

# %%
chevrolet_eng_hp_ = (df.make == 'chevrolet') & (df.model == 'impala')

# %%
df.loc[chevrolet_eng_hp_, 'engine_hp'] = df.loc[chevrolet_eng_hp_, 'engine_hp'].fillna(chevrolet_eng_hp_mean)
df[(df.make == 'chevrolet') & (df.model == 'impala')]
# Out:
#            make   model  year                  engine_fuel_type   engine_hp  \
# 5823  chevrolet  impala  2015                  regular_unleaded  195.000000
# 5824  chevrolet  impala  2015                  regular_unleaded  195.000000
# 5825  chevrolet  impala  2015  flex-fuel_(unleaded/natural_gas)  240.833333
# 5826  chevrolet  impala  2015          flex-fuel_(unleaded/e85)  305.000000
# 5827  chevrolet  impala  2015          flex-fuel_(unleaded/e85)  305.000000
# 5828  chevrolet  impala  2015                  regular_unleaded  195.000000
# 5829  chevrolet  impala  2015                  regular_unleaded  195.000000
# 5830  chevrolet  impala  2015  flex-fuel_(unleaded/natural_gas)  240.833333
# 5831  chevrolet  impala  2016  flex-fuel_(unleaded/natural_gas)  240.833333
# 5832  chevrolet  impala  2016          flex-fuel_(unleaded/e85)  305.000000
# 5833  chevrolet  impala  2016  flex-fuel_(unleaded/natural_gas)  240.833333
# ...

# %%
df[df['engine_hp'].isnull()]['make'].unique()
# Out:
# array(['nissan', 'mercedes-benz', 'lincoln', 'tesla', 'toyota', 'kia'],
#       dtype=object)

# %%
list(df[(df.make == 'nissan') & (df['engine_hp'].isnull())]['model'].unique())
# Out:
# ['leaf']

# %%
df[(df.make == 'nissan') & (df.model == 'leaf')]
# Out:
#         make model  year engine_fuel_type  engine_hp  engine_cylinders  \
# 6385  nissan  leaf  2014         electric        NaN               0.0
# 6386  nissan  leaf  2014         electric        NaN               0.0
# 6387  nissan  leaf  2014         electric        NaN               0.0
# 6388  nissan  leaf  2015         electric        NaN               0.0
# 6389  nissan  leaf  2015         electric        NaN               0.0
# 6390  nissan  leaf  2015         electric        NaN               0.0
# 6391  nissan  leaf  2015         electric        NaN               0.0
# 6392  nissan  leaf  2016         electric        NaN               0.0
# 6393  nissan  leaf  2016         electric        NaN               0.0
# 6394  nissan  leaf  2016         electric        NaN               0.0
#
#      transmission_type      driven_wheels number_of_doors market_category  \
# 6385      direct_drive  front_wheel_drive             4.0       hatchback
# ...

# %%
nissan_enghp_mean = df[(df.make == 'nissan') & (df.vehicle_style == '4dr_hatchback') & (df.market_category == 'hatchback') ]['engine_hp'].mean()
nissan_enghp_mean
# Out:
# 109.0

# %%
nissan_enghp = (df.make == 'nissan') & (df.model == 'leaf')
nissan_enghp
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
df.loc[nissan_enghp, 'engine_hp'] = df.loc[nissan_enghp, 'engine_hp'].fillna(nissan_enghp_mean)
df[(df.make == 'nissan') & (df.model == 'leaf')]
# Out:
#         make model  year engine_fuel_type  engine_hp  engine_cylinders  \
# 6385  nissan  leaf  2014         electric      109.0               0.0
# 6386  nissan  leaf  2014         electric      109.0               0.0
# 6387  nissan  leaf  2014         electric      109.0               0.0
# 6388  nissan  leaf  2015         electric      109.0               0.0
# 6389  nissan  leaf  2015         electric      109.0               0.0
# 6390  nissan  leaf  2015         electric      109.0               0.0
# 6391  nissan  leaf  2015         electric      109.0               0.0
# 6392  nissan  leaf  2016         electric      109.0               0.0
# 6393  nissan  leaf  2016         electric      109.0               0.0
# 6394  nissan  leaf  2016         electric      109.0               0.0
#
#      transmission_type      driven_wheels number_of_doors market_category  \
# 6385      direct_drive  front_wheel_drive             4.0       hatchback
# ...

# %%
df[df['engine_hp'].isnull()]['make'].unique()
# Out:
# array(['mercedes-benz', 'lincoln', 'tesla', 'toyota', 'kia'], dtype=object)

# %%
list(df[(df.make == 'mercedes-benz') & (df['engine_hp'].isnull())]['model'].unique())
# Out:
# ['m-class']

# %%
benz_enghp_mean = df[(df.make == 'mercedes-benz') & (df.model == 'm-class') & (df.engine_fuel_type == 'diesel')]['engine_hp'].mean()
benz_enghp_mean
# Out:
# 240.0

# %%
benz_enghp = (df.make == 'mercedes-benz') & (df.model == 'm-class') & (df.engine_fuel_type == 'diesel')

# %%
df.loc[benz_enghp, 'engine_hp'] = df.loc[benz_enghp, 'engine_hp'].fillna(benz_enghp_mean)
df[(df.make == 'mercedes-benz') & (df.model == 'm-class') & (df.engine_fuel_type == 'diesel')]
# Out:
#                make    model  year engine_fuel_type  engine_hp  \
# 6566  mercedes-benz  m-class  2013           diesel      240.0
# 6572  mercedes-benz  m-class  2014           diesel      240.0
# 6578  mercedes-benz  m-class  2015           diesel      240.0
#
#       engine_cylinders transmission_type    driven_wheels number_of_doors  \
# 6566               6.0         automatic  all_wheel_drive             4.0
# 6572               6.0         automatic  all_wheel_drive             4.0
# 6578               4.0         automatic  all_wheel_drive             4.0
#
#               market_category vehicle_size vehicle_style  highway_mpg  \
# 6566  crossover,luxury,diesel      midsize       4dr_suv           28
# 6572  crossover,luxury,diesel      midsize       4dr_suv           28
# 6578  crossover,luxury,diesel      midsize       4dr_suv           29
#
#       city_mpg  popularity   msrp  age
# 6566        20         617  51270    5
# 6572        20         617  51790    4
# ...

# %%
df[df['engine_hp'].isnull()]['make'].unique()
# Out:
# array(['lincoln', 'tesla', 'toyota', 'kia'], dtype=object)

# %%
list(df[(df.make == 'lincoln') & (df['engine_hp'].isnull())]['model'].unique())
# Out:
# ['mkz']

# %%
df[(df.make == 'lincoln') & (df.model == 'mkz') & (df['engine_hp'].isnull())]
# Out:
#          make model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 6908  lincoln   mkz  2017  regular_unleaded        NaN               4.0
# 6910  lincoln   mkz  2017  regular_unleaded        NaN               4.0
# 6916  lincoln   mkz  2017  regular_unleaded        NaN               4.0
# 6918  lincoln   mkz  2017  regular_unleaded        NaN               4.0
#
#      transmission_type      driven_wheels number_of_doors market_category  \
# 6908         automatic  front_wheel_drive             4.0   luxury,hybrid
# 6910         automatic  front_wheel_drive             4.0   luxury,hybrid
# 6916         automatic  front_wheel_drive             4.0   luxury,hybrid
# 6918         automatic  front_wheel_drive             4.0   luxury,hybrid
#
#      vehicle_size vehicle_style  highway_mpg  city_mpg  popularity   msrp  age
# 6908      midsize         sedan           38        41          61  35010    1
# ...

# %%
lincoln_enghp_mean = df[(df.make == 'lincoln') & (df.model == 'mkz') & (df.engine_fuel_type == 'regular_unleaded') & (df.driven_wheels == 'front_wheel_drive') & (df.market_category == 'luxury,hybrid')]['engine_hp'].mean()
lincoln_enghp_mean
# Out:
# 188.0

# %%
lincoln_enghp = (df.make == 'lincoln') & (df.model == 'mkz') & (df['engine_hp'].isnull())
lincoln_enghp
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
df.loc[lincoln_enghp, 'engine_hp'] = df.loc[lincoln_enghp, 'engine_hp'].fillna(lincoln_enghp_mean)
df[(df.make == 'lincoln') & (df.model == 'mkz') & (df['engine_hp'].isnull())]
# Out:
# Empty DataFrame
# Columns: [make, model, year, engine_fuel_type, engine_hp, engine_cylinders, transmission_type, driven_wheels, number_of_doors, market_category, vehicle_size, vehicle_style, highway_mpg, city_mpg, popularity, msrp, age]
# Index: []

# %%
df[df['engine_hp'].isnull()]['make'].unique()
# Out:
# array(['tesla', 'toyota', 'kia'], dtype=object)

# %%
list(df[(df.make == 'tesla') & (df['engine_hp'].isnull())]['model'].unique())
# Out:
# ['model_s']

# %%
df[(df.make == 'tesla') & (df.model == 'model_s') & (df['engine_hp'].isnull())]
# Out:
#        make    model  year engine_fuel_type  engine_hp  engine_cylinders  \
# 6921  tesla  model_s  2014         electric        NaN               0.0
# 6922  tesla  model_s  2014         electric        NaN               0.0
# 6923  tesla  model_s  2014         electric        NaN               0.0
# 6924  tesla  model_s  2014         electric        NaN               0.0
# 6925  tesla  model_s  2015         electric        NaN               0.0
# 6926  tesla  model_s  2015         electric        NaN               0.0
# 6927  tesla  model_s  2015         electric        NaN               0.0
# 6928  tesla  model_s  2015         electric        NaN               0.0
# 6929  tesla  model_s  2015         electric        NaN               0.0
# 6930  tesla  model_s  2016         electric        NaN               0.0
# 6931  tesla  model_s  2016         electric        NaN               0.0
# 6932  tesla  model_s  2016         electric        NaN               0.0
# ...

# %%
df[(df.make == 'tesla') & (df['engine_hp'].notnull())]
# Out:
# Empty DataFrame
# Columns: [make, model, year, engine_fuel_type, engine_hp, engine_cylinders, transmission_type, driven_wheels, number_of_doors, market_category, vehicle_size, vehicle_style, highway_mpg, city_mpg, popularity, msrp, age]
# Index: []

# %%
# considering exotic as luxury
tesla_rear_drive_mean = df[(df.engine_fuel_type == 'electric') & (df.driven_wheels == 'rear_wheel_drive') & (df['engine_hp'].notnull()) & (df.market_category == 'hatchback,luxury')]['engine_hp'].mean()
tesla_rear_drive_mean
# Out:
# 170.0

# %%
tesla_rear = (df.make == 'tesla') & (df.driven_wheels == 'rear_wheel_drive')
tesla_rear
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
df.loc[tesla_rear, 'engine_hp'] = df.loc[tesla_rear, 'engine_hp'].fillna(tesla_rear_drive_mean)
df[(df.make == 'tesla') & (df.driven_wheels == 'rear_wheel_drive')]
# Out:
#        make    model  year engine_fuel_type  engine_hp  engine_cylinders  \
# 6921  tesla  model_s  2014         electric      170.0               0.0
# 6922  tesla  model_s  2014         electric      170.0               0.0
# 6924  tesla  model_s  2014         electric      170.0               0.0
# 6925  tesla  model_s  2015         electric      170.0               0.0
# 6929  tesla  model_s  2015         electric      170.0               0.0
# 6933  tesla  model_s  2016         electric      170.0               0.0
# 6938  tesla  model_s  2016         electric      170.0               0.0
#
#      transmission_type     driven_wheels number_of_doors  \
# 6921      direct_drive  rear_wheel_drive             4.0
# 6922      direct_drive  rear_wheel_drive             4.0
# 6924      direct_drive  rear_wheel_drive             4.0
# 6925      direct_drive  rear_wheel_drive             4.0
# 6929      direct_drive  rear_wheel_drive             4.0
# ...

# %%
tesla_all_wheel_mean = df[(df.engine_fuel_type == 'electric') & (df['engine_hp'].notnull()) & ((df.market_category == 'hatchback,luxury') | (df.market_category.str.contains(r"\b(exotic)\b")))]['engine_hp'].mean()
tesla_all_wheel_mean
# Out:
# C:\Users\Lakshmeesh s reddy\AppData\Local\Temp\ipykernel_16328\1526185067.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   tesla_all_wheel_mean = df[(df.engine_fuel_type == 'electric') & (df['engine_hp'].notnull()) & ((df.market_category == 'hatchback,luxury') | (df.market_category.str.contains(r"\b(exotic)\b")))]['engine_hp'].mean()
# 171.5

# %%
tesla_all_wheel = (df.make == 'tesla') & (df.driven_wheels == 'all_wheel_drive')
tesla_all_wheel
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
df.loc[tesla_all_wheel,'engine_hp'] = df.loc[tesla_all_wheel,'engine_hp'].fillna(tesla_all_wheel_mean)

# %%
df[(df.make == 'tesla')]
# Out:
#        make    model  year engine_fuel_type  engine_hp  engine_cylinders  \
# 6921  tesla  model_s  2014         electric      170.0               0.0
# 6922  tesla  model_s  2014         electric      170.0               0.0
# 6923  tesla  model_s  2014         electric      171.5               0.0
# 6924  tesla  model_s  2014         electric      170.0               0.0
# 6925  tesla  model_s  2015         electric      170.0               0.0
# 6926  tesla  model_s  2015         electric      171.5               0.0
# 6927  tesla  model_s  2015         electric      171.5               0.0
# 6928  tesla  model_s  2015         electric      171.5               0.0
# 6929  tesla  model_s  2015         electric      170.0               0.0
# 6930  tesla  model_s  2016         electric      171.5               0.0
# 6931  tesla  model_s  2016         electric      171.5               0.0
# 6932  tesla  model_s  2016         electric      171.5               0.0
# ...

# %%
df[df['engine_hp'].isnull()]['make'].unique()
# Out:
# array(['toyota', 'kia'], dtype=object)

# %%
list(df[(df.make == 'toyota') & (df['engine_hp'].isnull())]['model'].unique())
# Out:
# ['rav4_ev']

# %%
df[(df.make == 'toyota') & (df.model == 'rav4_ev')]
# Out:
#         make    model  year engine_fuel_type  engine_hp  engine_cylinders  \
# 8373  toyota  rav4_ev  2012         electric      154.0               NaN
# 8374  toyota  rav4_ev  2013         electric        NaN               0.0
# 8375  toyota  rav4_ev  2014         electric        NaN               0.0
#
#      transmission_type      driven_wheels number_of_doors market_category  \
# 8373      direct_drive  front_wheel_drive             4.0       crossover
# 8374      direct_drive  front_wheel_drive             4.0       crossover
# 8375      direct_drive  front_wheel_drive             4.0       crossover
#
#      vehicle_size vehicle_style  highway_mpg  city_mpg  popularity   msrp  age
# 8373      midsize       4dr_suv           74        78        2031  49800    6
# 8374      midsize       4dr_suv           74        78        2031  49800    5
# 8375      midsize       4dr_suv           74        78        2031  49800    4

# %%
toyota_ele_mean = df[(df.make == 'toyota') & (df.model == 'rav4_ev')]['engine_hp'].mean()
toyota_ele_mean
# Out:
# 154.0

# %%
toyota_ele = (df.make == 'toyota') & (df.model == 'rav4_ev')
toyota_ele
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
df.loc[toyota_ele, 'engine_hp'] = df.loc[toyota_ele, 'engine_hp'].fillna(toyota_ele_mean)
df[(df.make == 'toyota') & (df.model == 'rav4_ev')]
# Out:
#         make    model  year engine_fuel_type  engine_hp  engine_cylinders  \
# 8373  toyota  rav4_ev  2012         electric      154.0               NaN
# 8374  toyota  rav4_ev  2013         electric      154.0               0.0
# 8375  toyota  rav4_ev  2014         electric      154.0               0.0
#
#      transmission_type      driven_wheels number_of_doors market_category  \
# 8373      direct_drive  front_wheel_drive             4.0       crossover
# 8374      direct_drive  front_wheel_drive             4.0       crossover
# 8375      direct_drive  front_wheel_drive             4.0       crossover
#
#      vehicle_size vehicle_style  highway_mpg  city_mpg  popularity   msrp  age
# 8373      midsize       4dr_suv           74        78        2031  49800    6
# 8374      midsize       4dr_suv           74        78        2031  49800    5
# 8375      midsize       4dr_suv           74        78        2031  49800    4

# %%
df[df['engine_hp'].isnull()]['make'].unique()
# Out:
# array(['kia'], dtype=object)

# %%
list(df[(df.make == 'kia') & (df['engine_hp'].isnull())]['model'].unique())
# Out:
# ['soul_ev']

# %%
df[(df.make == 'kia') & (df.model == 'soul_ev')]
# Out:
#      make    model  year engine_fuel_type  engine_hp  engine_cylinders  \
# 9850  kia  soul_ev  2015         electric        NaN               0.0
# 9851  kia  soul_ev  2015         electric        NaN               0.0
# 9852  kia  soul_ev  2016         electric        NaN               0.0
# 9853  kia  soul_ev  2016         electric        NaN               0.0
# 9854  kia  soul_ev  2016         electric        NaN               0.0
#
#      transmission_type      driven_wheels number_of_doors market_category  \
# 9850      direct_drive  front_wheel_drive             4.0             NaN
# 9851      direct_drive  front_wheel_drive             4.0             NaN
# 9852      direct_drive  front_wheel_drive             4.0             NaN
# 9853      direct_drive  front_wheel_drive             4.0             NaN
# 9854      direct_drive  front_wheel_drive             4.0             NaN
#
#      vehicle_size vehicle_style  highway_mpg  city_mpg  popularity   msrp  age
# ...

# %%
kia_ele_mean = df[(df.make == 'kia') & (df['engine_hp'].notnull()) & (df.vehicle_size == 'compact') & (df.driven_wheels == 'front_wheel_drive')]['engine_hp'].mean()
kia_ele_mean
# Out:
# 156.91379310344828

# %%
kia_ele = (df.make == 'kia') & (df.model == 'soul_ev')
kia_ele
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
df.loc[kia_ele, 'engine_hp'] = df.loc[kia_ele, 'engine_hp'].fillna(kia_ele_mean)
df[(df.make == 'kia') & (df.model == 'soul_ev')]
# Out:
#      make    model  year engine_fuel_type   engine_hp  engine_cylinders  \
# 9850  kia  soul_ev  2015         electric  156.913793               0.0
# 9851  kia  soul_ev  2015         electric  156.913793               0.0
# 9852  kia  soul_ev  2016         electric  156.913793               0.0
# 9853  kia  soul_ev  2016         electric  156.913793               0.0
# 9854  kia  soul_ev  2016         electric  156.913793               0.0
#
#      transmission_type      driven_wheels number_of_doors market_category  \
# 9850      direct_drive  front_wheel_drive             4.0             NaN
# 9851      direct_drive  front_wheel_drive             4.0             NaN
# 9852      direct_drive  front_wheel_drive             4.0             NaN
# 9853      direct_drive  front_wheel_drive             4.0             NaN
# 9854      direct_drive  front_wheel_drive             4.0             NaN
#
#      vehicle_size vehicle_style  highway_mpg  city_mpg  popularity   msrp  age
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   make               11914 non-null  object
#  1   model              11914 non-null  object
#  2   year               11914 non-null  int64
#  3   engine_fuel_type   11914 non-null  object
#  4   engine_hp          11914 non-null  float64
#  5   engine_cylinders   11884 non-null  float64
#  6   transmission_type  11914 non-null  object
#  7   driven_wheels      11914 non-null  object
#  8   number_of_doors    11908 non-null  object
#  9   market_category    8172 non-null   object
#  10  vehicle_size       11914 non-null  object
#  11  vehicle_style      11914 non-null  object
#  12  highway_mpg        11914 non-null  int64
#  13  city_mpg           11914 non-null  int64
#  14  popularity         11914 non-null  int64
#  15  msrp               11914 non-null  int64
# ...

# %%
ele_eng_cy = df.engine_fuel_type == 'electric'

# %%
df.loc[ele_eng_cy, 'engine_cylinders'] = df.loc[ele_eng_cy, 'engine_cylinders'].fillna(0.0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   make               11914 non-null  object
#  1   model              11914 non-null  object
#  2   year               11914 non-null  int64
#  3   engine_fuel_type   11914 non-null  object
#  4   engine_hp          11914 non-null  float64
#  5   engine_cylinders   11894 non-null  float64
#  6   transmission_type  11914 non-null  object
#  7   driven_wheels      11914 non-null  object
#  8   number_of_doors    11908 non-null  object
#  9   market_category    8172 non-null   object
#  10  vehicle_size       11914 non-null  object
#  11  vehicle_style      11914 non-null  object
#  12  highway_mpg        11914 non-null  int64
#  13  city_mpg           11914 non-null  int64
#  14  popularity         11914 non-null  int64
#  15  msrp               11914 non-null  int64
# ...

# %%
df[(df['engine_cylinders'].isnull()) & (df.make == 'mazda')]
# Out:
#        make model  year             engine_fuel_type  engine_hp  \
# 8695  mazda  rx-7  1993             regular_unleaded      255.0
# 8696  mazda  rx-7  1994             regular_unleaded      255.0
# 8697  mazda  rx-7  1995             regular_unleaded      255.0
# 8698  mazda  rx-8  2009  premium_unleaded_(required)      232.0
# 8699  mazda  rx-8  2009  premium_unleaded_(required)      212.0
# 8700  mazda  rx-8  2009  premium_unleaded_(required)      232.0
# 8701  mazda  rx-8  2009  premium_unleaded_(required)      232.0
# 8702  mazda  rx-8  2009  premium_unleaded_(required)      232.0
# 8703  mazda  rx-8  2009  premium_unleaded_(required)      212.0
# 8704  mazda  rx-8  2009  premium_unleaded_(required)      212.0
# 8705  mazda  rx-8  2010  premium_unleaded_(required)      232.0
# 8706  mazda  rx-8  2010  premium_unleaded_(required)      212.0
# 8707  mazda  rx-8  2010  premium_unleaded_(required)      212.0
# 8708  mazda  rx-8  2010  premium_unleaded_(required)      232.0
# ...

# %%
rx7_mean = df[(df.make == 'mazda') & (df.transmission_type == 'manual') & (df.engine_fuel_type == 'regular_unleaded') & (df.driven_wheels == 'rear_wheel_drive') & (df.number_of_doors == 2.0) & (df.year <= 1995)]['engine_cylinders'].mean()
rx7_mean
# Out:
# 6.0

# %%
ma_cy = (df.make == 'mazda') & (df.model == 'rx-7')
ma_cy
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
df.loc[ma_cy,'engine_cylinders'] = df.loc[ma_cy,'engine_cylinders'].fillna(rx7_mean)

# %%
df[(df.make == 'mazda') & (df.model == 'rx-7')]
# Out:
#        make model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 8695  mazda  rx-7  1993  regular_unleaded      255.0               6.0
# 8696  mazda  rx-7  1994  regular_unleaded      255.0               6.0
# 8697  mazda  rx-7  1995  regular_unleaded      255.0               6.0
#
#      transmission_type     driven_wheels number_of_doors  \
# 8695            manual  rear_wheel_drive             2.0
# 8696            manual  rear_wheel_drive             2.0
# 8697            manual  rear_wheel_drive             2.0
#
#                 market_category vehicle_size vehicle_style  highway_mpg  \
# 8695  factory_tuner,performance      compact         coupe           23
# 8696  factory_tuner,performance      compact         coupe           23
# 8697  factory_tuner,performance      compact         coupe           23
#
#       city_mpg  popularity  msrp  age
# 8695        15         586  7523   25
# 8696        15         586  8147   24
# 8697        15         586  8839   23

# %%
df[(df['engine_cylinders'].isnull()) & (df.make == 'mazda')]
# Out:
#        make model  year             engine_fuel_type  engine_hp  \
# 8698  mazda  rx-8  2009  premium_unleaded_(required)      232.0
# 8699  mazda  rx-8  2009  premium_unleaded_(required)      212.0
# 8700  mazda  rx-8  2009  premium_unleaded_(required)      232.0
# 8701  mazda  rx-8  2009  premium_unleaded_(required)      232.0
# 8702  mazda  rx-8  2009  premium_unleaded_(required)      232.0
# 8703  mazda  rx-8  2009  premium_unleaded_(required)      212.0
# 8704  mazda  rx-8  2009  premium_unleaded_(required)      212.0
# 8705  mazda  rx-8  2010  premium_unleaded_(required)      232.0
# 8706  mazda  rx-8  2010  premium_unleaded_(required)      212.0
# 8707  mazda  rx-8  2010  premium_unleaded_(required)      212.0
# 8708  mazda  rx-8  2010  premium_unleaded_(required)      232.0
# 8709  mazda  rx-8  2010  premium_unleaded_(required)      232.0
# 8710  mazda  rx-8  2011  premium_unleaded_(required)      212.0
# 8711  mazda  rx-8  2011  premium_unleaded_(required)      232.0
# ...

# %%
df[(df.make == 'mazda') & (df.transmission_type == 'manual') & (df.engine_fuel_type == 'regular_unleaded') & (df.driven_wheels == 'rear_wheel_drive') & (df.number_of_doors == 4.0) & (df.year >= 1995)]
# Out:
#         make            model  year  engine_fuel_type  engine_hp  \
# 1689   mazda  b-series_pickup  1998  regular_unleaded      119.0
# 1707   mazda  b-series_pickup  1999  regular_unleaded      119.0
# 1726   mazda   b-series_truck  2007  regular_unleaded      148.0
# 1727   mazda   b-series_truck  2007  regular_unleaded      148.0
# 1737   mazda         b-series  2001  regular_unleaded      150.0
# 1741   mazda         b-series  2001  regular_unleaded      207.0
# 10832  mazda            truck  2002  regular_unleaded      207.0
# 10840  mazda            truck  2003  regular_unleaded      147.0
# 10842  mazda            truck  2003  regular_unleaded      207.0
#
#        engine_cylinders transmission_type     driven_wheels number_of_doors  \
# 1689                4.0            manual  rear_wheel_drive             4.0
# 1707                4.0            manual  rear_wheel_drive             4.0
# 1726                6.0            manual  rear_wheel_drive             4.0
# ...

# %%
engine_cy = (df.make == 'mazda') & (df['engine_cylinders'].isnull())
engine_cy
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
df.loc[engine_cy, 'engine_cylinders'] = df.loc[engine_cy, 'engine_cylinders'].fillna(6.0)
df[(df.make == 'mazda') & (df['engine_cylinders'].isnull())]
# Out:
# Empty DataFrame
# Columns: [make, model, year, engine_fuel_type, engine_hp, engine_cylinders, transmission_type, driven_wheels, number_of_doors, market_category, vehicle_size, vehicle_style, highway_mpg, city_mpg, popularity, msrp, age]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   make               11914 non-null  object
#  1   model              11914 non-null  object
#  2   year               11914 non-null  int64
#  3   engine_fuel_type   11914 non-null  object
#  4   engine_hp          11914 non-null  float64
#  5   engine_cylinders   11914 non-null  float64
#  6   transmission_type  11914 non-null  object
#  7   driven_wheels      11914 non-null  object
#  8   number_of_doors    11908 non-null  object
#  9   market_category    8172 non-null   object
#  10  vehicle_size       11914 non-null  object
#  11  vehicle_style      11914 non-null  object
#  12  highway_mpg        11914 non-null  int64
#  13  city_mpg           11914 non-null  int64
#  14  popularity         11914 non-null  int64
#  15  msrp               11914 non-null  int64
# ...

# %%
df[df['number_of_doors'].isnull()]
# Out:
#          make    model  year             engine_fuel_type  engine_hp  \
# 4666  ferrari       ff  2013  premium_unleaded_(required)      651.0
# 6930    tesla  model_s  2016                     electric      171.5
# 6931    tesla  model_s  2016                     electric      171.5
# 6932    tesla  model_s  2016                     electric      171.5
# 6933    tesla  model_s  2016                     electric      170.0
# 6934    tesla  model_s  2016                     electric      171.5
#
#       engine_cylinders transmission_type     driven_wheels number_of_doors  \
# 4666              12.0  automated_manual   all_wheel_drive             NaN
# 6930               0.0      direct_drive   all_wheel_drive             NaN
# 6931               0.0      direct_drive   all_wheel_drive             NaN
# 6932               0.0      direct_drive   all_wheel_drive             NaN
# 6933               0.0      direct_drive  rear_wheel_drive             NaN
# ...

# %%
df[(df.make == 'ferrari') & (df.model == 'ff')]
# Out:
#          make model  year             engine_fuel_type  engine_hp  \
# 4666  ferrari    ff  2013  premium_unleaded_(required)      651.0
# 4667  ferrari    ff  2014  premium_unleaded_(required)      651.0
# 4668  ferrari    ff  2015  premium_unleaded_(required)      651.0
#
#       engine_cylinders transmission_type    driven_wheels number_of_doors  \
# 4666              12.0  automated_manual  all_wheel_drive             NaN
# 4667              12.0  automated_manual  all_wheel_drive             2.0
# 4668              12.0  automated_manual  all_wheel_drive             2.0
#
#               market_category vehicle_size vehicle_style  highway_mpg  \
# 4666  exotic,high-performance        large         coupe           16
# 4667  exotic,high-performance        large         coupe           16
# 4668  exotic,high-performance        large         coupe           16
#
#       city_mpg  popularity    msrp  age
# 4666        11        2774  295000    5
# ...

# %%
fer_nodoor = (df.make == 'ferrari') & (df.model == 'ff')
fer_nodoor
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
df.loc[fer_nodoor, 'number_of_doors'] = df.loc[fer_nodoor, 'number_of_doors'].fillna(2.0)
df[(df.make == 'ferrari') & (df.model == 'ff')]
# Out:
#          make model  year             engine_fuel_type  engine_hp  \
# 4666  ferrari    ff  2013  premium_unleaded_(required)      651.0
# 4667  ferrari    ff  2014  premium_unleaded_(required)      651.0
# 4668  ferrari    ff  2015  premium_unleaded_(required)      651.0
#
#       engine_cylinders transmission_type    driven_wheels number_of_doors  \
# 4666              12.0  automated_manual  all_wheel_drive             2.0
# 4667              12.0  automated_manual  all_wheel_drive             2.0
# 4668              12.0  automated_manual  all_wheel_drive             2.0
#
#               market_category vehicle_size vehicle_style  highway_mpg  \
# 4666  exotic,high-performance        large         coupe           16
# 4667  exotic,high-performance        large         coupe           16
# 4668  exotic,high-performance        large         coupe           16
#
#       city_mpg  popularity    msrp  age
# 4666        11        2774  295000    5
# ...

# %%
df[df['number_of_doors'].isnull()]
# Out:
#        make    model  year engine_fuel_type  engine_hp  engine_cylinders  \
# 6930  tesla  model_s  2016         electric      171.5               0.0
# 6931  tesla  model_s  2016         electric      171.5               0.0
# 6932  tesla  model_s  2016         electric      171.5               0.0
# 6933  tesla  model_s  2016         electric      170.0               0.0
# 6934  tesla  model_s  2016         electric      171.5               0.0
#
#      transmission_type     driven_wheels number_of_doors  \
# 6930      direct_drive   all_wheel_drive             NaN
# 6931      direct_drive   all_wheel_drive             NaN
# 6932      direct_drive   all_wheel_drive             NaN
# 6933      direct_drive  rear_wheel_drive             NaN
# 6934      direct_drive   all_wheel_drive             NaN
#
#               market_category vehicle_size vehicle_style  highway_mpg  \
# 6930       exotic,performance        large         sedan          105
# ...

# %%
df[(df.make == 'tesla') & (df.model == 'model_s')]
# Out:
#        make    model  year engine_fuel_type  engine_hp  engine_cylinders  \
# 6921  tesla  model_s  2014         electric      170.0               0.0
# 6922  tesla  model_s  2014         electric      170.0               0.0
# 6923  tesla  model_s  2014         electric      171.5               0.0
# 6924  tesla  model_s  2014         electric      170.0               0.0
# 6925  tesla  model_s  2015         electric      170.0               0.0
# 6926  tesla  model_s  2015         electric      171.5               0.0
# 6927  tesla  model_s  2015         electric      171.5               0.0
# 6928  tesla  model_s  2015         electric      171.5               0.0
# 6929  tesla  model_s  2015         electric      170.0               0.0
# 6930  tesla  model_s  2016         electric      171.5               0.0
# 6931  tesla  model_s  2016         electric      171.5               0.0
# 6932  tesla  model_s  2016         electric      171.5               0.0
# ...

# %%
tesla_nodoor = (df.make == 'tesla') & (df.model == 'model_s')
tesla_nodoor
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
df.loc[tesla_nodoor, 'number_of_doors'] = df.loc[tesla_nodoor, 'number_of_doors'].fillna(4.0)
df[df['number_of_doors'].isnull()]
# Out:
# Empty DataFrame
# Columns: [make, model, year, engine_fuel_type, engine_hp, engine_cylinders, transmission_type, driven_wheels, number_of_doors, market_category, vehicle_size, vehicle_style, highway_mpg, city_mpg, popularity, msrp, age]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   make               11914 non-null  object
#  1   model              11914 non-null  object
#  2   year               11914 non-null  int64
#  3   engine_fuel_type   11914 non-null  object
#  4   engine_hp          11914 non-null  float64
#  5   engine_cylinders   11914 non-null  float64
#  6   transmission_type  11914 non-null  object
#  7   driven_wheels      11914 non-null  object
#  8   number_of_doors    11914 non-null  object
#  9   market_category    8172 non-null   object
#  10  vehicle_size       11914 non-null  object
#  11  vehicle_style      11914 non-null  object
#  12  highway_mpg        11914 non-null  int64
#  13  city_mpg           11914 non-null  int64
#  14  popularity         11914 non-null  int64
#  15  msrp               11914 non-null  int64
# ...

# %%
df[df['market_category'].isnull()]
# Out:
#          make     model  year                engine_fuel_type  engine_hp  \
# 87     nissan     200sx  1996                regular_unleaded      115.0
# 88     nissan     200sx  1996                regular_unleaded      115.0
# 91     nissan     200sx  1997                regular_unleaded      115.0
# 92     nissan     200sx  1997                regular_unleaded      115.0
# 93     nissan     200sx  1998                regular_unleaded      115.0
# ...       ...       ...   ...                             ...        ...
# 11794  subaru        xt  1991                regular_unleaded      145.0
# 11809  toyota  yaris_ia  2017                regular_unleaded      106.0
# 11810  toyota  yaris_ia  2017                regular_unleaded      106.0
# 11867     gmc     yukon  2015  premium_unleaded_(recommended)      420.0
# 11868     gmc     yukon  2015  premium_unleaded_(recommended)      420.0
#
#        engine_cylinders transmission_type      driven_wheels number_of_doors  \
# ...

# %%
df[(df.make == 'nissan') & (df.model == '200sx')]
# Out:
#       make  model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 87  nissan  200sx  1996  regular_unleaded      115.0               4.0
# 88  nissan  200sx  1996  regular_unleaded      115.0               4.0
# 89  nissan  200sx  1996  regular_unleaded      140.0               4.0
# 90  nissan  200sx  1997  regular_unleaded      140.0               4.0
# 91  nissan  200sx  1997  regular_unleaded      115.0               4.0
# 92  nissan  200sx  1997  regular_unleaded      115.0               4.0
# 93  nissan  200sx  1998  regular_unleaded      115.0               4.0
# 94  nissan  200sx  1998  regular_unleaded      115.0               4.0
# 95  nissan  200sx  1998  regular_unleaded      140.0               4.0
#
#    transmission_type      driven_wheels number_of_doors market_category  \
# 87            manual  front_wheel_drive             2.0             NaN
# 88            manual  front_wheel_drive             2.0             NaN
# ...

# %%
lst_200x_ = list(df[(df.make == 'nissan') & (df.model == '200sx')]['market_category'].unique())
lst_200x_
# Out:
# [nan, 'performance']

# %%
mar_cat_val = [x for x in lst_200x_ if isinstance(x, str)]
mar_cat_val
# Out:
# ['performance']

# %%
mar_cat_val[0]
# Out:
# 'performance'

# %%
ni_200sx_mar_cat = (df.make == 'nissan') & (df.model == '200sx')

# %%
df.loc[ni_200sx_mar_cat,'market_category'] = df.loc[ni_200sx_mar_cat,'market_category'].fillna(mar_cat_val[0])
df[(df.make == 'nissan') & (df.model == '200sx')]
# Out:
#       make  model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 87  nissan  200sx  1996  regular_unleaded      115.0               4.0
# 88  nissan  200sx  1996  regular_unleaded      115.0               4.0
# 89  nissan  200sx  1996  regular_unleaded      140.0               4.0
# 90  nissan  200sx  1997  regular_unleaded      140.0               4.0
# 91  nissan  200sx  1997  regular_unleaded      115.0               4.0
# 92  nissan  200sx  1997  regular_unleaded      115.0               4.0
# 93  nissan  200sx  1998  regular_unleaded      115.0               4.0
# 94  nissan  200sx  1998  regular_unleaded      115.0               4.0
# 95  nissan  200sx  1998  regular_unleaded      140.0               4.0
#
#    transmission_type      driven_wheels number_of_doors market_category  \
# 87            manual  front_wheel_drive             2.0     performance
# 88            manual  front_wheel_drive             2.0     performance
# ...

# %%
dum_df = df[df['market_category'].isnull()]
dum_df
# Out:
#            make     model  year                engine_fuel_type  engine_hp  \
# 203    chrysler       300  2015                regular_unleaded      300.0
# 204    chrysler       300  2015                regular_unleaded      292.0
# 205    chrysler       300  2015                regular_unleaded      292.0
# 206    chrysler       300  2015                regular_unleaded      292.0
# 209    chrysler       300  2015                regular_unleaded      292.0
# ...         ...       ...   ...                             ...        ...
# 11794    subaru        xt  1991                regular_unleaded      145.0
# 11809    toyota  yaris_ia  2017                regular_unleaded      106.0
# 11810    toyota  yaris_ia  2017                regular_unleaded      106.0
# 11867       gmc     yukon  2015  premium_unleaded_(recommended)      420.0
# 11868       gmc     yukon  2015  premium_unleaded_(recommended)      420.0
#
# ...

# %%
df[(df.make == 'chrysler') & (df.model == '300')]
# Out:
#          make model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 203  chrysler   300  2015  regular_unleaded      300.0               6.0
# 204  chrysler   300  2015  regular_unleaded      292.0               6.0
# 205  chrysler   300  2015  regular_unleaded      292.0               6.0
# 206  chrysler   300  2015  regular_unleaded      292.0               6.0
# 207  chrysler   300  2015  regular_unleaded      300.0               6.0
# 208  chrysler   300  2015  regular_unleaded      292.0               6.0
# 209  chrysler   300  2015  regular_unleaded      292.0               6.0
# 210  chrysler   300  2015  regular_unleaded      292.0               6.0
# 211  chrysler   300  2016  regular_unleaded      300.0               6.0
# 212  chrysler   300  2016  regular_unleaded      300.0               6.0
# 213  chrysler   300  2016  regular_unleaded      292.0               6.0
# 214  chrysler   300  2016  regular_unleaded      292.0               6.0
# ...

# %%
lst_300_ = list(df[(df.make == 'chrysler') & (df.model == '300')]['market_category'].unique())
lst_300_
# Out:
# [nan, 'performance']

# %%
mar_cat_val_2 = [x for x in lst_200x_ if isinstance(x, str)]
mar_cat_val_2
# Out:
# ['performance']

# %%
mar_cat_val_2[0]
# Out:
# 'performance'

# %%
chrysler_300_mar_cat = (df.make == 'chrysler') & (df.model == '300')

# %%
df.loc[chrysler_300_mar_cat,'market_category'] = df.loc[chrysler_300_mar_cat,'market_category'].fillna(mar_cat_val_2[0])
df[(df.make == 'chrysler') & (df.model == '300s')]
# Out:
# Empty DataFrame
# Columns: [make, model, year, engine_fuel_type, engine_hp, engine_cylinders, transmission_type, driven_wheels, number_of_doors, market_category, vehicle_size, vehicle_style, highway_mpg, city_mpg, popularity, msrp, age]
# Index: []

# %%
dum_df = df[df['market_category'].isnull()]
dum_df
# Out:
#          make     model  year                engine_fuel_type  engine_hp  \
# 360     mazda         3  2015                regular_unleaded      155.0
# 361     mazda         3  2015                regular_unleaded      155.0
# 362     mazda         3  2015                regular_unleaded      155.0
# 368     mazda         3  2015                regular_unleaded      155.0
# 373     mazda         3  2015                regular_unleaded      155.0
# ...       ...       ...   ...                             ...        ...
# 11794  subaru        xt  1991                regular_unleaded      145.0
# 11809  toyota  yaris_ia  2017                regular_unleaded      106.0
# 11810  toyota  yaris_ia  2017                regular_unleaded      106.0
# 11867     gmc     yukon  2015  premium_unleaded_(recommended)      420.0
# 11868     gmc     yukon  2015  premium_unleaded_(recommended)      420.0
#
#        engine_cylinders transmission_type      driven_wheels number_of_doors  \
# ...

# %%
lst_3_ = list(df[(df.make == 'mazda') & (df.model == '3')]['market_category'].unique())
lst_3_
# Out:
# ['performance', nan, 'hatchback,performance', 'hatchback']

# %%
df[(df.make == 'mazda') & (df.model == '3') & (df.transmission_type == 'automatic') & (df.vehicle_style == 'sedan')]
# Out:
#       make model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 359  mazda     3  2015  regular_unleaded      184.0               4.0
# 360  mazda     3  2015  regular_unleaded      155.0               4.0
# 365  mazda     3  2015  regular_unleaded      184.0               4.0
# 368  mazda     3  2015  regular_unleaded      155.0               4.0
# 375  mazda     3  2015  regular_unleaded      155.0               4.0
# 379  mazda     3  2015  regular_unleaded      155.0               4.0
# 381  mazda     3  2016  regular_unleaded      155.0               4.0
# 385  mazda     3  2016  regular_unleaded      155.0               4.0
# 390  mazda     3  2016  regular_unleaded      155.0               4.0
# 394  mazda     3  2016  regular_unleaded      184.0               4.0
# 397  mazda     3  2016  regular_unleaded      184.0               4.0
# 398  mazda     3  2017  regular_unleaded      155.0               4.0
# ...

# %%
mazda_3_mar_cat = (df.make == 'mazda') & (df.model == '3') & (df.transmission_type == 'automatic') & (df.vehicle_style == 'sedan')

# %%
df.loc[mazda_3_mar_cat,'market_category'] = df.loc[mazda_3_mar_cat,'market_category'].fillna('performance')
df[(df.make == 'mazda') & (df.model == '3') & (df.transmission_type == 'automatic') & (df.vehicle_style == 'sedan')]
# Out:
#       make model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 359  mazda     3  2015  regular_unleaded      184.0               4.0
# 360  mazda     3  2015  regular_unleaded      155.0               4.0
# 365  mazda     3  2015  regular_unleaded      184.0               4.0
# 368  mazda     3  2015  regular_unleaded      155.0               4.0
# 375  mazda     3  2015  regular_unleaded      155.0               4.0
# 379  mazda     3  2015  regular_unleaded      155.0               4.0
# 381  mazda     3  2016  regular_unleaded      155.0               4.0
# 385  mazda     3  2016  regular_unleaded      155.0               4.0
# 390  mazda     3  2016  regular_unleaded      155.0               4.0
# 394  mazda     3  2016  regular_unleaded      184.0               4.0
# 397  mazda     3  2016  regular_unleaded      184.0               4.0
# 398  mazda     3  2017  regular_unleaded      155.0               4.0
# ...

# %%
df[(df.make == 'mazda') & (df.model == '3') & (df.transmission_type == 'automatic') & (df.vehicle_style == '4dr_hatchback') &(df.engine_hp == 155.0)]
# Out:
#       make model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 367  mazda     3  2015  regular_unleaded      155.0               4.0
# 370  mazda     3  2015  regular_unleaded      155.0               4.0
# 371  mazda     3  2015  regular_unleaded      155.0               4.0
# 384  mazda     3  2016  regular_unleaded      155.0               4.0
# 386  mazda     3  2016  regular_unleaded      155.0               4.0
# 391  mazda     3  2016  regular_unleaded      155.0               4.0
# 402  mazda     3  2017  regular_unleaded      155.0               4.0
# 408  mazda     3  2017  regular_unleaded      155.0               4.0
#
#     transmission_type      driven_wheels number_of_doors market_category  \
# 367         automatic  front_wheel_drive             4.0       hatchback
# 370         automatic  front_wheel_drive             4.0       hatchback
# 371         automatic  front_wheel_drive             4.0       hatchback
# ...

# %%
mazda_3_mar_cat_last = (df.make == 'mazda') & (df.model == '3') & (df.transmission_type == 'automatic') & (df.vehicle_style == '4dr_hatchback') &(df.engine_hp == 155.0)
mazda_3_mar_cat_last
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
du = (df.make == 'mazda') & (df.model == '3') & (df['market_category'].isnull())

# %%
df.loc[du, 'market_category'] = df.loc[du, 'market_category'].fillna('hatchback')

# %%
df[(df.make == 'mazda') & (df.model == '3')]
# Out:
#       make model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 358  mazda     3  2015  regular_unleaded      184.0               4.0
# 359  mazda     3  2015  regular_unleaded      184.0               4.0
# 360  mazda     3  2015  regular_unleaded      155.0               4.0
# 361  mazda     3  2015  regular_unleaded      155.0               4.0
# 362  mazda     3  2015  regular_unleaded      155.0               4.0
# 363  mazda     3  2015  regular_unleaded      184.0               4.0
# 364  mazda     3  2015  regular_unleaded      184.0               4.0
# 365  mazda     3  2015  regular_unleaded      184.0               4.0
# 366  mazda     3  2015  regular_unleaded      184.0               4.0
# 367  mazda     3  2015  regular_unleaded      155.0               4.0
# 368  mazda     3  2015  regular_unleaded      155.0               4.0
# 369  mazda     3  2015  regular_unleaded      155.0               4.0
# ...

# %%
dum_df = df[df['market_category'].isnull()]
dum_df
# Out:
#          make     model  year                engine_fuel_type  engine_hp  \
# 479    toyota   4runner  2014                regular_unleaded      270.0
# 480    toyota   4runner  2014                regular_unleaded      270.0
# 481    toyota   4runner  2014                regular_unleaded      270.0
# 482    toyota   4runner  2014                regular_unleaded      270.0
# 483    toyota   4runner  2014                regular_unleaded      270.0
# ...       ...       ...   ...                             ...        ...
# 11794  subaru        xt  1991                regular_unleaded      145.0
# 11809  toyota  yaris_ia  2017                regular_unleaded      106.0
# 11810  toyota  yaris_ia  2017                regular_unleaded      106.0
# 11867     gmc     yukon  2015  premium_unleaded_(recommended)      420.0
# 11868     gmc     yukon  2015  premium_unleaded_(recommended)      420.0
#
#        engine_cylinders transmission_type      driven_wheels number_of_doors  \
# ...

# %%
list(df[(df.make == 'toyota') & (df.model == '4runner')]['market_category'].unique())
# Out:
# [nan]

# %%
df[(df.make == 'toyota') & df['market_category'].isnull()]
# Out:
#          make     model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 479    toyota   4runner  2014  regular_unleaded      270.0               6.0
# 480    toyota   4runner  2014  regular_unleaded      270.0               6.0
# 481    toyota   4runner  2014  regular_unleaded      270.0               6.0
# 482    toyota   4runner  2014  regular_unleaded      270.0               6.0
# 483    toyota   4runner  2014  regular_unleaded      270.0               6.0
# ...       ...       ...   ...               ...        ...               ...
# 11061  toyota    tundra  2017  regular_unleaded      381.0               8.0
# 11062  toyota    tundra  2017  regular_unleaded      381.0               8.0
# 11064  toyota    tundra  2017  regular_unleaded      381.0               8.0
# 11809  toyota  yaris_ia  2017  regular_unleaded      106.0               4.0
# 11810  toyota  yaris_ia  2017  regular_unleaded      106.0               4.0
#
# ...

# %%
df[(df.make == 'toyota') & (df.engine_fuel_type == 'regular_unleaded') & (df.vehicle_size == 'midsize') & (df.engine_cylinders == 6)]
# Out:
#          make    model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 479    toyota  4runner  2014  regular_unleaded      270.0               6.0
# 480    toyota  4runner  2014  regular_unleaded      270.0               6.0
# 481    toyota  4runner  2014  regular_unleaded      270.0               6.0
# 482    toyota  4runner  2014  regular_unleaded      270.0               6.0
# 483    toyota  4runner  2014  regular_unleaded      270.0               6.0
# ...       ...      ...   ...               ...        ...               ...
# 11283  toyota    venza  2014  regular_unleaded      268.0               6.0
# 11285  toyota    venza  2014  regular_unleaded      268.0               6.0
# 11288  toyota    venza  2015  regular_unleaded      268.0               6.0
# 11290  toyota    venza  2015  regular_unleaded      268.0               6.0
# 11293  toyota    venza  2015  regular_unleaded      268.0               6.0
#
# ...

# %%
T1 = (df.make == 'toyota') & (df.engine_fuel_type == 'regular_unleaded') & (df.vehicle_size == 'midsize') & (df.engine_cylinders == 6)
T1
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
df.loc[T1, 'market_category'] = df.loc[T1, 'market_category'].fillna('crossover,performance')

# %%
df[(df.make == 'toyota') & (df.engine_fuel_type == 'regular_unleaded') & (df.vehicle_size == 'midsize') & (df.engine_cylinders == 6)]
# Out:
#          make    model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 479    toyota  4runner  2014  regular_unleaded      270.0               6.0
# 480    toyota  4runner  2014  regular_unleaded      270.0               6.0
# 481    toyota  4runner  2014  regular_unleaded      270.0               6.0
# 482    toyota  4runner  2014  regular_unleaded      270.0               6.0
# 483    toyota  4runner  2014  regular_unleaded      270.0               6.0
# ...       ...      ...   ...               ...        ...               ...
# 11283  toyota    venza  2014  regular_unleaded      268.0               6.0
# 11285  toyota    venza  2014  regular_unleaded      268.0               6.0
# 11288  toyota    venza  2015  regular_unleaded      268.0               6.0
# 11290  toyota    venza  2015  regular_unleaded      268.0               6.0
# 11293  toyota    venza  2015  regular_unleaded      268.0               6.0
#
# ...

# %%
df[(df.make == 'toyota') & df['market_category'].isnull()]
# Out:
#          make         model  year  engine_fuel_type  engine_hp  \
# 2212   toyota  camry_solara  2006  regular_unleaded      157.0
# 2216   toyota  camry_solara  2006  regular_unleaded      157.0
# 2218   toyota  camry_solara  2006  regular_unleaded      157.0
# 2219   toyota  camry_solara  2006  regular_unleaded      157.0
# 2221   toyota  camry_solara  2006  regular_unleaded      157.0
# ...       ...           ...   ...               ...        ...
# 11061  toyota        tundra  2017  regular_unleaded      381.0
# 11062  toyota        tundra  2017  regular_unleaded      381.0
# 11064  toyota        tundra  2017  regular_unleaded      381.0
# 11809  toyota      yaris_ia  2017  regular_unleaded      106.0
# 11810  toyota      yaris_ia  2017  regular_unleaded      106.0
#
#        engine_cylinders transmission_type      driven_wheels number_of_doors  \
# 2212                4.0         automatic  front_wheel_drive             2.0
# ...

# %%
df[(df.make == 'toyota') & (df.engine_fuel_type == 'regular_unleaded')  & (df.engine_cylinders == 8.0)]
# Out:
#          make         model  year  engine_fuel_type  engine_hp  \
# 6347   toyota  land_cruiser  2015  regular_unleaded      381.0
# 6348   toyota  land_cruiser  2016  regular_unleaded      381.0
# 6349   toyota  land_cruiser  2017  regular_unleaded      381.0
# 9114   toyota       sequoia  2015  regular_unleaded      381.0
# 9115   toyota       sequoia  2015  regular_unleaded      381.0
# ...       ...           ...   ...               ...        ...
# 11059  toyota        tundra  2017  regular_unleaded      381.0
# 11060  toyota        tundra  2017  regular_unleaded      381.0
# 11061  toyota        tundra  2017  regular_unleaded      381.0
# 11062  toyota        tundra  2017  regular_unleaded      381.0
# 11064  toyota        tundra  2017  regular_unleaded      381.0
#
#        engine_cylinders transmission_type     driven_wheels number_of_doors  \
# 6347                8.0         automatic  four_wheel_drive             4.0
# ...

# %%
df[(df.vehicle_style == 'crew_cab_pickup') & (df.engine_fuel_type == 'regular_unleaded')]
# Out:
#          make   model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 1777   subaru    baja  2004  regular_unleaded      165.0               4.0
# 1780   subaru    baja  2004  regular_unleaded      165.0               4.0
# 1782   subaru    baja  2005  regular_unleaded      165.0               4.0
# 1786   subaru    baja  2005  regular_unleaded      165.0               4.0
# 1788   subaru    baja  2006  regular_unleaded      165.0               4.0
# ...       ...     ...   ...               ...        ...               ...
# 11047  toyota  tundra  2017  regular_unleaded      381.0               8.0
# 11057  toyota  tundra  2017  regular_unleaded      381.0               8.0
# 11061  toyota  tundra  2017  regular_unleaded      381.0               8.0
# 11062  toyota  tundra  2017  regular_unleaded      381.0               8.0
# 11064  toyota  tundra  2017  regular_unleaded      381.0               8.0
#
# ...

# %%
T2 = (df.vehicle_style == 'crew_cab_pickup') & (df.engine_fuel_type == 'regular_unleaded') & (df.make == 'toyota')
T2
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
df.loc[T2, 'market_category'] = df.loc[T2, 'market_category'].fillna('crossover')
df[(df.vehicle_style == 'crew_cab_pickup') & (df.engine_fuel_type == 'regular_unleaded') & (df.make == 'toyota')]
# Out:
#          make   model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 10166  toyota  tacoma  2015  regular_unleaded      236.0               6.0
# 10167  toyota  tacoma  2015  regular_unleaded      159.0               4.0
# 10173  toyota  tacoma  2015  regular_unleaded      159.0               4.0
# 10174  toyota  tacoma  2015  regular_unleaded      236.0               6.0
# 10175  toyota  tacoma  2015  regular_unleaded      236.0               6.0
# ...       ...     ...   ...               ...        ...               ...
# 11047  toyota  tundra  2017  regular_unleaded      381.0               8.0
# 11057  toyota  tundra  2017  regular_unleaded      381.0               8.0
# 11061  toyota  tundra  2017  regular_unleaded      381.0               8.0
# 11062  toyota  tundra  2017  regular_unleaded      381.0               8.0
# 11064  toyota  tundra  2017  regular_unleaded      381.0               8.0
#
# ...

# %%
df[(df.make == 'toyota') & (df['market_category'].isnull())]
# Out:
#          make         model  year  engine_fuel_type  engine_hp  \
# 2212   toyota  camry_solara  2006  regular_unleaded      157.0
# 2216   toyota  camry_solara  2006  regular_unleaded      157.0
# 2218   toyota  camry_solara  2006  regular_unleaded      157.0
# 2219   toyota  camry_solara  2006  regular_unleaded      157.0
# 2221   toyota  camry_solara  2006  regular_unleaded      157.0
# ...       ...           ...   ...               ...        ...
# 11058  toyota        tundra  2017  regular_unleaded      381.0
# 11059  toyota        tundra  2017  regular_unleaded      381.0
# 11060  toyota        tundra  2017  regular_unleaded      381.0
# 11809  toyota      yaris_ia  2017  regular_unleaded      106.0
# 11810  toyota      yaris_ia  2017  regular_unleaded      106.0
#
#        engine_cylinders transmission_type      driven_wheels number_of_doors  \
# 2212                4.0         automatic  front_wheel_drive             2.0
# ...

# %%
T3 = (df.vehicle_style == 'extended_cab_pickup') & (df.engine_fuel_type == 'regular_unleaded') & (df.make == 'toyota')
T3
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
df.loc[T3, 'market_category'] = df.loc[T3, 'market_category'].fillna('crossover')
df[(df.vehicle_style == 'extended_cab_pickup') & (df.engine_fuel_type == 'regular_unleaded') & (df.make == 'toyota')]
# Out:
#          make   model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 7565   toyota  pickup  1993  regular_unleaded      150.0               6.0
# 7566   toyota  pickup  1993  regular_unleaded      150.0               6.0
# 7567   toyota  pickup  1993  regular_unleaded      150.0               6.0
# 7568   toyota  pickup  1993  regular_unleaded      150.0               6.0
# 7569   toyota  pickup  1993  regular_unleaded      116.0               4.0
# ...       ...     ...   ...               ...        ...               ...
# 11055  toyota  tundra  2017  regular_unleaded      310.0               8.0
# 11056  toyota  tundra  2017  regular_unleaded      310.0               8.0
# 11058  toyota  tundra  2017  regular_unleaded      381.0               8.0
# 11059  toyota  tundra  2017  regular_unleaded      381.0               8.0
# 11060  toyota  tundra  2017  regular_unleaded      381.0               8.0
#
# ...

# %%
df[(df.make == 'toyota') & (df['market_category'].isnull())]
# Out:
#          make         model  year  engine_fuel_type  engine_hp  \
# 2212   toyota  camry_solara  2006  regular_unleaded      157.0
# 2216   toyota  camry_solara  2006  regular_unleaded      157.0
# 2218   toyota  camry_solara  2006  regular_unleaded      157.0
# 2219   toyota  camry_solara  2006  regular_unleaded      157.0
# 2221   toyota  camry_solara  2006  regular_unleaded      157.0
# ...       ...           ...   ...               ...        ...
# 11013  toyota        tundra  2016  regular_unleaded      381.0
# 11017  toyota        tundra  2017  regular_unleaded      381.0
# 11029  toyota        tundra  2017  regular_unleaded      381.0
# 11809  toyota      yaris_ia  2017  regular_unleaded      106.0
# 11810  toyota      yaris_ia  2017  regular_unleaded      106.0
#
#        engine_cylinders transmission_type      driven_wheels number_of_doors  \
# 2212                4.0         automatic  front_wheel_drive             2.0
# ...

# %%
df[(df.vehicle_style == 'sedan') & (df.engine_cylinders == 4.0) & (df.engine_fuel_type == 'regular_unleaded') & (df.driven_wheels == 'front_wheel_drive')]
# Out:
#          make     model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 358     mazda         3  2015  regular_unleaded      184.0               4.0
# 359     mazda         3  2015  regular_unleaded      184.0               4.0
# 360     mazda         3  2015  regular_unleaded      155.0               4.0
# 361     mazda         3  2015  regular_unleaded      155.0               4.0
# 362     mazda         3  2015  regular_unleaded      155.0               4.0
# ...       ...       ...   ...               ...        ...               ...
# 11359  nissan     versa  2017  regular_unleaded      109.0               4.0
# 11360  nissan     versa  2017  regular_unleaded      109.0               4.0
# 11361  nissan     versa  2017  regular_unleaded      109.0               4.0
# 11809  toyota  yaris_ia  2017  regular_unleaded      106.0               4.0
# 11810  toyota  yaris_ia  2017  regular_unleaded      106.0               4.0
#
# ...

# %%
## performance has higher hp therefor we are choosing hatchback

T4 = (df.vehicle_style == 'sedan') & (df.vehicle_size == 'compact') &(df.engine_fuel_type == 'regular_unleaded') & (df.make == 'toyota')
T4
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
df.loc[T4, 'market_category'] = df.loc[T4, 'market_category'].fillna('hatchback')

# %%
df[(df.make == 'toyota') & df['market_category'].isnull()]
# Out:
#          make         model  year  engine_fuel_type  engine_hp  \
# 2212   toyota  camry_solara  2006  regular_unleaded      157.0
# 2216   toyota  camry_solara  2006  regular_unleaded      157.0
# 2218   toyota  camry_solara  2006  regular_unleaded      157.0
# 2219   toyota  camry_solara  2006  regular_unleaded      157.0
# 2221   toyota  camry_solara  2006  regular_unleaded      157.0
# ...       ...           ...   ...               ...        ...
# 10965  toyota        tundra  2015  regular_unleaded      381.0
# 11000  toyota        tundra  2016  regular_unleaded      381.0
# 11013  toyota        tundra  2016  regular_unleaded      381.0
# 11017  toyota        tundra  2017  regular_unleaded      381.0
# 11029  toyota        tundra  2017  regular_unleaded      381.0
#
#        engine_cylinders transmission_type      driven_wheels number_of_doors  \
# 2212                4.0         automatic  front_wheel_drive             2.0
# ...

# %%
df[(df.vehicle_style == 'regular_cab_pickup') & (df.engine_fuel_type == 'regular_unleaded') & (df.make == 'toyota')]
# Out:
#          make   model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 7570   toyota  pickup  1993  regular_unleaded      116.0               4.0
# 7572   toyota  pickup  1994  regular_unleaded      150.0               6.0
# 7573   toyota  pickup  1994  regular_unleaded      116.0               4.0
# 7574   toyota  pickup  1994  regular_unleaded      116.0               4.0
# 7575   toyota  pickup  1994  regular_unleaded      116.0               4.0
# 7585   toyota  pickup  1995  regular_unleaded      116.0               4.0
# 7587   toyota  pickup  1995  regular_unleaded      116.0               4.0
# 7589   toyota  pickup  1995  regular_unleaded      150.0               6.0
# 7590   toyota  pickup  1995  regular_unleaded      116.0               4.0
# 10154  toyota    t100  1996  regular_unleaded      150.0               4.0
# 10158  toyota    t100  1997  regular_unleaded      150.0               4.0
# ...

# %%
T5 = (df.vehicle_style == 'regular_cab_pickup') & (df.engine_fuel_type == 'regular_unleaded') & (df.make == 'toyota')
T5
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
df.loc[T5, 'market_category'] = df.loc[T5, 'market_category'].fillna('crossover')

# %%
df[(df.make == 'toyota') & (df['market_category'].isnull())]
# Out:
#          make         model  year  engine_fuel_type  engine_hp  \
# 2212   toyota  camry_solara  2006  regular_unleaded      157.0
# 2216   toyota  camry_solara  2006  regular_unleaded      157.0
# 2218   toyota  camry_solara  2006  regular_unleaded      157.0
# 2219   toyota  camry_solara  2006  regular_unleaded      157.0
# 2221   toyota  camry_solara  2006  regular_unleaded      157.0
# ...       ...           ...   ...               ...        ...
# 10330  toyota        tercel  1996  regular_unleaded       93.0
# 10332  toyota        tercel  1996  regular_unleaded       93.0
# 10333  toyota        tercel  1997  regular_unleaded       93.0
# 10335  toyota        tercel  1997  regular_unleaded       93.0
# 10336  toyota        tercel  1998  regular_unleaded       93.0
#
#        engine_cylinders transmission_type      driven_wheels number_of_doors  \
# 2212                4.0         automatic  front_wheel_drive             2.0
# ...

# %%
df[(df.driven_wheels == 'front_wheel_drive') & (df.number_of_doors == 2.0) & (df.engine_fuel_type == 'regular_unleaded') & (df.vehicle_style == 'coupe') & (df.vehicle_size == 'compact')]
# Out:
#          make   model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 87     nissan   200sx  1996  regular_unleaded      115.0               4.0
# 88     nissan   200sx  1996  regular_unleaded      115.0               4.0
# 89     nissan   200sx  1996  regular_unleaded      140.0               4.0
# 90     nissan   200sx  1997  regular_unleaded      140.0               4.0
# 91     nissan   200sx  1997  regular_unleaded      115.0               4.0
# ...       ...     ...   ...               ...        ...               ...
# 10333  toyota  tercel  1997  regular_unleaded       93.0               4.0
# 10335  toyota  tercel  1997  regular_unleaded       93.0               4.0
# 10336  toyota  tercel  1998  regular_unleaded       93.0               4.0
# 11792  subaru      xt  1991  regular_unleaded       97.0               4.0
# 11793  subaru      xt  1991  regular_unleaded      145.0               6.0
#
# ...

# %%
T6 = (df.driven_wheels == 'front_wheel_drive') & (df.number_of_doors == 2.0) & (df.engine_fuel_type == 'regular_unleaded') & (df.vehicle_style == 'coupe') & (df.vehicle_size == 'compact') & (df.make == 'toyota')
T6
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
df.loc[T6, 'market_category'] = df.loc[T6, 'market_category'].fillna('performance')

# %%
df[(df.make == 'toyota') & (df['market_category'].isnull())]
# Out:
#         make         model  year  engine_fuel_type  engine_hp  \
# 2212  toyota  camry_solara  2006  regular_unleaded      157.0
# 2216  toyota  camry_solara  2006  regular_unleaded      157.0
# 2218  toyota  camry_solara  2006  regular_unleaded      157.0
# 2219  toyota  camry_solara  2006  regular_unleaded      157.0
# 2221  toyota  camry_solara  2006  regular_unleaded      157.0
# ...      ...           ...   ...               ...        ...
# 9248  toyota        sienna  2017  regular_unleaded      296.0
# 9249  toyota        sienna  2017  regular_unleaded      296.0
# 9250  toyota        sienna  2017  regular_unleaded      296.0
# 9251  toyota        sienna  2017  regular_unleaded      296.0
# 9252  toyota        sienna  2017  regular_unleaded      296.0
#
#       engine_cylinders transmission_type      driven_wheels number_of_doors  \
# 2212               4.0         automatic  front_wheel_drive             2.0
# ...

# %%
df[(df.vehicle_style == 'coupe') & (df.vehicle_size == 'midsize') & (df.driven_wheels == 'front_wheel_drive') & (df.engine_cylinders == 4.0)]
# Out:
#              make         model  year  engine_fuel_type  engine_hp  \
# 1215        honda        accord  2015  regular_unleaded      185.0
# 1216        honda        accord  2015  regular_unleaded      185.0
# 1218        honda        accord  2015  regular_unleaded      185.0
# 1222        honda        accord  2015  regular_unleaded      185.0
# 1224        honda        accord  2015  regular_unleaded      185.0
# 1230        honda        accord  2015  regular_unleaded      185.0
# 1235        honda        accord  2016  regular_unleaded      185.0
# 1240        honda        accord  2016  regular_unleaded      185.0
# 1241        honda        accord  2016  regular_unleaded      185.0
# 1244        honda        accord  2016  regular_unleaded      185.0
# 1247        honda        accord  2016  regular_unleaded      185.0
# 1248        honda        accord  2016  regular_unleaded      185.0
# 1250        honda        accord  2016  regular_unleaded      185.0
# ...

# %%
df[(df.vehicle_style == 'coupe') & (df['market_category'].notnull()) & (df.engine_cylinders == 4.0) & (df.vehicle_size == 'midsize') & (df.engine_fuel_type == 'regular_unleaded')]
# Out:
#        make  model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 757   volvo    780  1990  regular_unleaded      188.0               4.0
# 3036  volvo  coupe  1991  regular_unleaded      188.0               4.0
#
#      transmission_type     driven_wheels number_of_doors market_category  \
# 757          automatic  rear_wheel_drive             2.0          luxury
# 3036         automatic  rear_wheel_drive             2.0          luxury
#
#      vehicle_size vehicle_style  highway_mpg  city_mpg  popularity  msrp  age
# 757       midsize         coupe           20        16         870  2000   28
# 3036      midsize         coupe           20        17         870  2000   27

# %%
T7 = (df.vehicle_style == 'coupe') & (df.vehicle_size == 'midsize') & (df.driven_wheels == 'front_wheel_drive') & (df.engine_cylinders == 4.0)
T7
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
df.loc[T7, 'market_category'] = df.loc[T7, 'market_category'].fillna('luxury')

# %%
df[df['market_category'].isnull()]
# Out:
#          make  model  year                engine_fuel_type  engine_hp  \
# 545      fiat    500  2015  premium_unleaded_(recommended)      101.0
# 546      fiat    500  2015  premium_unleaded_(recommended)      101.0
# 549      fiat    500  2015  premium_unleaded_(recommended)      101.0
# 558      fiat    500  2016  premium_unleaded_(recommended)      101.0
# 560      fiat    500  2016  premium_unleaded_(recommended)      101.0
# ...       ...    ...   ...                             ...        ...
# 11792  subaru     xt  1991                regular_unleaded       97.0
# 11793  subaru     xt  1991                regular_unleaded      145.0
# 11794  subaru     xt  1991                regular_unleaded      145.0
# 11867     gmc  yukon  2015  premium_unleaded_(recommended)      420.0
# 11868     gmc  yukon  2015  premium_unleaded_(recommended)      420.0
#
#        engine_cylinders transmission_type      driven_wheels number_of_doors  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   make               11914 non-null  object
#  1   model              11914 non-null  object
#  2   year               11914 non-null  int64
#  3   engine_fuel_type   11914 non-null  object
#  4   engine_hp          11914 non-null  float64
#  5   engine_cylinders   11914 non-null  float64
#  6   transmission_type  11914 non-null  object
#  7   driven_wheels      11914 non-null  object
#  8   number_of_doors    11914 non-null  object
#  9   market_category    8599 non-null   object
#  10  vehicle_size       11914 non-null  object
#  11  vehicle_style      11914 non-null  object
#  12  highway_mpg        11914 non-null  int64
#  13  city_mpg           11914 non-null  int64
#  14  popularity         11914 non-null  int64
#  15  msrp               11914 non-null  int64
# ...

# %%
df[(df.make == 'fiat') & (df.model == '500') & (df.vehicle_style == 'convertible')]
# Out:
#      make model  year                engine_fuel_type  engine_hp  \
# 542  fiat   500  2015  premium_unleaded_(recommended)      160.0
# 545  fiat   500  2015  premium_unleaded_(recommended)      101.0
# 546  fiat   500  2015  premium_unleaded_(recommended)      101.0
# 549  fiat   500  2015  premium_unleaded_(recommended)      101.0
# 553  fiat   500  2016  premium_unleaded_(recommended)      160.0
# 558  fiat   500  2016  premium_unleaded_(recommended)      101.0
# 560  fiat   500  2016  premium_unleaded_(recommended)      101.0
# 563  fiat   500  2016  premium_unleaded_(recommended)      101.0
# 566  fiat   500  2017  premium_unleaded_(recommended)      101.0
# 567  fiat   500  2017  premium_unleaded_(recommended)      101.0
# 568  fiat   500  2017  premium_unleaded_(recommended)      160.0
#
#      engine_cylinders transmission_type      driven_wheels number_of_doors  \
# 542               4.0            manual  front_wheel_drive             2.0
# ...

# %%
F1 = (df.make == 'fiat') & (df.model == '500') & (df.vehicle_style == 'convertible')
F1
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
df.loc[F1, 'market_category'] = df.loc[F1, 'market_category'].fillna('factory_tuner,performance')

# %%
df[(df.make == 'fiat') & (df.model == '500') & (df.vehicle_style == 'convertible')]
# Out:
#      make model  year                engine_fuel_type  engine_hp  \
# 542  fiat   500  2015  premium_unleaded_(recommended)      160.0
# 545  fiat   500  2015  premium_unleaded_(recommended)      101.0
# 546  fiat   500  2015  premium_unleaded_(recommended)      101.0
# 549  fiat   500  2015  premium_unleaded_(recommended)      101.0
# 553  fiat   500  2016  premium_unleaded_(recommended)      160.0
# 558  fiat   500  2016  premium_unleaded_(recommended)      101.0
# 560  fiat   500  2016  premium_unleaded_(recommended)      101.0
# 563  fiat   500  2016  premium_unleaded_(recommended)      101.0
# 566  fiat   500  2017  premium_unleaded_(recommended)      101.0
# 567  fiat   500  2017  premium_unleaded_(recommended)      101.0
# 568  fiat   500  2017  premium_unleaded_(recommended)      160.0
#
#      engine_cylinders transmission_type      driven_wheels number_of_doors  \
# 542               4.0            manual  front_wheel_drive             2.0
# ...

# %%
df[df['market_category'].isnull()]
# Out:
#          make  model  year                engine_fuel_type  engine_hp  \
# 570      fiat   500l  2015  premium_unleaded_(recommended)      160.0
# 571      fiat   500l  2015  premium_unleaded_(recommended)      160.0
# 572      fiat   500l  2015  premium_unleaded_(recommended)      160.0
# 573      fiat   500l  2015  premium_unleaded_(recommended)      160.0
# 574      fiat   500l  2015  premium_unleaded_(recommended)      160.0
# ...       ...    ...   ...                             ...        ...
# 11792  subaru     xt  1991                regular_unleaded       97.0
# 11793  subaru     xt  1991                regular_unleaded      145.0
# 11794  subaru     xt  1991                regular_unleaded      145.0
# 11867     gmc  yukon  2015  premium_unleaded_(recommended)      420.0
# 11868     gmc  yukon  2015  premium_unleaded_(recommended)      420.0
#
#        engine_cylinders transmission_type      driven_wheels number_of_doors  \
# ...

# %%
df[(df.make == 'fiat') & (df.model == '500l')]
# Out:
#      make model  year                engine_fuel_type  engine_hp  \
# 570  fiat  500l  2015  premium_unleaded_(recommended)      160.0
# 571  fiat  500l  2015  premium_unleaded_(recommended)      160.0
# 572  fiat  500l  2015  premium_unleaded_(recommended)      160.0
# 573  fiat  500l  2015  premium_unleaded_(recommended)      160.0
# 574  fiat  500l  2015  premium_unleaded_(recommended)      160.0
# 575  fiat  500l  2016  premium_unleaded_(recommended)      160.0
# 576  fiat  500l  2016  premium_unleaded_(recommended)      160.0
# 577  fiat  500l  2016  premium_unleaded_(recommended)      160.0
# 578  fiat  500l  2016  premium_unleaded_(recommended)      160.0
# 579  fiat  500l  2016  premium_unleaded_(recommended)      160.0
# 580  fiat  500l  2017  premium_unleaded_(recommended)      160.0
# 581  fiat  500l  2017  premium_unleaded_(recommended)      160.0
# 582  fiat  500l  2017  premium_unleaded_(recommended)      160.0
#
# ...

# %%
df[(df['market_category'].notnull())& (df.vehicle_size == 'compact') & (df.engine_fuel_type == 'premium_unleaded_(recommended)') & (df.driven_wheels == 'front_wheel_drive') & (df.vehicle_style == 'wagon')]
# Out:
#             make model  year                engine_fuel_type  engine_hp  \
# 824         saab   9-3  2009  premium_unleaded_(recommended)      210.0
# 829         saab   9-3  2009  premium_unleaded_(recommended)      210.0
# 830         saab   9-3  2009  premium_unleaded_(recommended)      210.0
# 838         saab   9-3  2010  premium_unleaded_(recommended)      207.0
# 844         saab   9-3  2010  premium_unleaded_(recommended)      207.0
# 849         saab   9-3  2011  premium_unleaded_(recommended)      210.0
# 850         saab   9-3  2011  premium_unleaded_(recommended)      210.0
# 5710   chevrolet   hhr  2009  premium_unleaded_(recommended)      260.0
# 5712   chevrolet   hhr  2009  premium_unleaded_(recommended)      260.0
# 5717   chevrolet   hhr  2010  premium_unleaded_(recommended)      260.0
# 11109      volvo   v50  2009  premium_unleaded_(recommended)      168.0
# 11112      volvo   v50  2010  premium_unleaded_(recommended)      168.0
#
# ...

# %%
F2 = (df.make == 'fiat') & (df.model == '500l')
F2
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
df.loc[F2, 'market_category'] = df.loc[F2, 'market_category'].fillna('luxury')
df[(df.make == 'fiat') & (df.model == '500l')]
# Out:
#      make model  year                engine_fuel_type  engine_hp  \
# 570  fiat  500l  2015  premium_unleaded_(recommended)      160.0
# 571  fiat  500l  2015  premium_unleaded_(recommended)      160.0
# 572  fiat  500l  2015  premium_unleaded_(recommended)      160.0
# 573  fiat  500l  2015  premium_unleaded_(recommended)      160.0
# 574  fiat  500l  2015  premium_unleaded_(recommended)      160.0
# 575  fiat  500l  2016  premium_unleaded_(recommended)      160.0
# 576  fiat  500l  2016  premium_unleaded_(recommended)      160.0
# 577  fiat  500l  2016  premium_unleaded_(recommended)      160.0
# 578  fiat  500l  2016  premium_unleaded_(recommended)      160.0
# 579  fiat  500l  2016  premium_unleaded_(recommended)      160.0
# 580  fiat  500l  2017  premium_unleaded_(recommended)      160.0
# 581  fiat  500l  2017  premium_unleaded_(recommended)      160.0
# 582  fiat  500l  2017  premium_unleaded_(recommended)      160.0
#
# ...

# %%
df[df['market_category'].isnull()]
# Out:
#          make  model  year                engine_fuel_type  engine_hp  \
# 623     mazda      5  2013                regular_unleaded      157.0
# 624     mazda      5  2013                regular_unleaded      157.0
# 625     mazda      5  2013                regular_unleaded      157.0
# 626     mazda      5  2013                regular_unleaded      157.0
# 627     mazda      5  2014                regular_unleaded      157.0
# ...       ...    ...   ...                             ...        ...
# 11792  subaru     xt  1991                regular_unleaded       97.0
# 11793  subaru     xt  1991                regular_unleaded      145.0
# 11794  subaru     xt  1991                regular_unleaded      145.0
# 11867     gmc  yukon  2015  premium_unleaded_(recommended)      420.0
# 11868     gmc  yukon  2015  premium_unleaded_(recommended)      420.0
#
#        engine_cylinders transmission_type      driven_wheels number_of_doors  \
# ...

# %%
df[(df.make == 'mazda') & (df.model == '5')]
# Out:
#       make model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 623  mazda     5  2013  regular_unleaded      157.0               4.0
# 624  mazda     5  2013  regular_unleaded      157.0               4.0
# 625  mazda     5  2013  regular_unleaded      157.0               4.0
# 626  mazda     5  2013  regular_unleaded      157.0               4.0
# 627  mazda     5  2014  regular_unleaded      157.0               4.0
# 628  mazda     5  2014  regular_unleaded      157.0               4.0
# 629  mazda     5  2014  regular_unleaded      157.0               4.0
# 630  mazda     5  2014  regular_unleaded      157.0               4.0
# 631  mazda     5  2015  regular_unleaded      157.0               4.0
# 632  mazda     5  2015  regular_unleaded      157.0               4.0
# 633  mazda     5  2015  regular_unleaded      157.0               4.0
#
#     transmission_type      driven_wheels number_of_doors market_category  \
# ...

# %%
df[(df.make == 'mazda') & (df.engine_fuel_type == 'regular_unleaded') & (df.engine_cylinders == 4.0) & (df.driven_wheels == 'front_wheel_drive') & (df.vehicle_size == 'compact')]
# Out:
#         make    model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 112    mazda        2  2012  regular_unleaded      100.0               4.0
# 113    mazda        2  2012  regular_unleaded      100.0               4.0
# 114    mazda        2  2012  regular_unleaded      100.0               4.0
# 115    mazda        2  2012  regular_unleaded      100.0               4.0
# 116    mazda        2  2013  regular_unleaded      100.0               4.0
# ...      ...      ...   ...               ...        ...               ...
# 10818  mazda  tribute  2010  regular_unleaded      171.0               4.0
# 10822  mazda  tribute  2011  regular_unleaded      171.0               4.0
# 10824  mazda  tribute  2011  regular_unleaded      171.0               4.0
# 10826  mazda  tribute  2011  regular_unleaded      171.0               4.0
# 10828  mazda  tribute  2011  regular_unleaded      171.0               4.0
#
# ...

# %%
df[(df.engine_fuel_type == 'regular_unleaded') & (df.engine_cylinders == 4.0) & (df.driven_wheels == 'front_wheel_drive') & (df.vehicle_size == 'compact') & (df.number_of_doors == 4.0)]
# Out:
#          make  model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 112     mazda      2  2012  regular_unleaded      100.0               4.0
# 113     mazda      2  2012  regular_unleaded      100.0               4.0
# 114     mazda      2  2012  regular_unleaded      100.0               4.0
# 115     mazda      2  2012  regular_unleaded      100.0               4.0
# 116     mazda      2  2013  regular_unleaded      100.0               4.0
# ...       ...    ...   ...               ...        ...               ...
# 11824  toyota  yaris  2016  regular_unleaded      106.0               4.0
# 11828  toyota  yaris  2017  regular_unleaded      106.0               4.0
# 11829  toyota  yaris  2017  regular_unleaded      106.0               4.0
# 11830  toyota  yaris  2017  regular_unleaded      106.0               4.0
# 11831  toyota  yaris  2017  regular_unleaded      106.0               4.0
#
#       transmission_type      driven_wheels number_of_doors market_category  \
# ...

# %%
M_5 = (df.make == 'mazda') & (df.model == '5')
M_5
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
df.loc[M_5, 'market_category'] = df.loc[M_5, 'market_category'].fillna('hatchback')
df[(df.make == 'mazda') & (df.model == '5')]
# Out:
#       make model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 623  mazda     5  2013  regular_unleaded      157.0               4.0
# 624  mazda     5  2013  regular_unleaded      157.0               4.0
# 625  mazda     5  2013  regular_unleaded      157.0               4.0
# 626  mazda     5  2013  regular_unleaded      157.0               4.0
# 627  mazda     5  2014  regular_unleaded      157.0               4.0
# 628  mazda     5  2014  regular_unleaded      157.0               4.0
# 629  mazda     5  2014  regular_unleaded      157.0               4.0
# 630  mazda     5  2014  regular_unleaded      157.0               4.0
# 631  mazda     5  2015  regular_unleaded      157.0               4.0
# 632  mazda     5  2015  regular_unleaded      157.0               4.0
# 633  mazda     5  2015  regular_unleaded      157.0               4.0
#
#     transmission_type      driven_wheels number_of_doors market_category  \
# ...

# %%
df[df['market_category'].isnull()]
# Out:
#           make  model  year                engine_fuel_type  engine_hp  \
# 674    pontiac   6000  1990                regular_unleaded      140.0
# 675    pontiac   6000  1990                regular_unleaded      110.0
# 676    pontiac   6000  1990                regular_unleaded      140.0
# 677    pontiac   6000  1990                regular_unleaded      140.0
# 678    pontiac   6000  1990                regular_unleaded      140.0
# ...        ...    ...   ...                             ...        ...
# 11792   subaru     xt  1991                regular_unleaded       97.0
# 11793   subaru     xt  1991                regular_unleaded      145.0
# 11794   subaru     xt  1991                regular_unleaded      145.0
# 11867      gmc  yukon  2015  premium_unleaded_(recommended)      420.0
# 11868      gmc  yukon  2015  premium_unleaded_(recommended)      420.0
#
#        engine_cylinders transmission_type      driven_wheels number_of_doors  \
# ...

# %%
df[(df.make == 'pontiac') & (df.model == '6000')]
# Out:
#         make model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 674  pontiac  6000  1990  regular_unleaded      140.0               6.0
# 675  pontiac  6000  1990  regular_unleaded      110.0               4.0
# 676  pontiac  6000  1990  regular_unleaded      140.0               6.0
# 677  pontiac  6000  1990  regular_unleaded      140.0               6.0
# 678  pontiac  6000  1990  regular_unleaded      140.0               6.0
# 679  pontiac  6000  1991  regular_unleaded      140.0               6.0
# 680  pontiac  6000  1991  regular_unleaded      140.0               6.0
# 681  pontiac  6000  1991  regular_unleaded      110.0               4.0
#
#     transmission_type      driven_wheels number_of_doors market_category  \
# 674         automatic  front_wheel_drive             4.0             NaN
# 675         automatic  front_wheel_drive             4.0             NaN
# 676         automatic  front_wheel_drive             4.0             NaN
# ...

# %%
df[(df.make == 'pontiac') & (df.engine_fuel_type == 'regular_unleaded') & (df['market_category'].notnull()) & (df.number_of_doors == 4.0) & (df.vehicle_size == 'midsize')]
# Out:
#          make       model  year  engine_fuel_type  engine_hp  \
# 1670  pontiac       aztek  2003  regular_unleaded      185.0
# 1671  pontiac       aztek  2003  regular_unleaded      185.0
# 1672  pontiac       aztek  2004  regular_unleaded      185.0
# 1673  pontiac       aztek  2004  regular_unleaded      185.0
# 1674  pontiac       aztek  2005  regular_unleaded      185.0
# 1675  pontiac       aztek  2005  regular_unleaded      185.0
# 5183  pontiac          g6  2008  regular_unleaded      252.0
# 5186  pontiac          g6  2008  regular_unleaded      219.0
# 5187  pontiac          g6  2009  regular_unleaded      252.0
# 5189  pontiac          g6  2009  regular_unleaded      221.0
# 5195  pontiac          g6  2009  regular_unleaded      164.0
# 5196  pontiac          g6  2009  regular_unleaded      252.0
# 5504  pontiac  grand_prix  2006  regular_unleaded      303.0
# 5506  pontiac  grand_prix  2007  regular_unleaded      303.0
#
# ...

# %%
P_6000 = (df.make == 'pontiac') & (df.model == '6000')
P_6000
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
df.loc[P_6000, 'market_category'] = df.loc[P_6000, 'market_category'].fillna('performance')
df[(df.make == 'pontiac') & (df.model == '6000')]
# Out:
#         make model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 674  pontiac  6000  1990  regular_unleaded      140.0               6.0
# 675  pontiac  6000  1990  regular_unleaded      110.0               4.0
# 676  pontiac  6000  1990  regular_unleaded      140.0               6.0
# 677  pontiac  6000  1990  regular_unleaded      140.0               6.0
# 678  pontiac  6000  1990  regular_unleaded      140.0               6.0
# 679  pontiac  6000  1991  regular_unleaded      140.0               6.0
# 680  pontiac  6000  1991  regular_unleaded      140.0               6.0
# 681  pontiac  6000  1991  regular_unleaded      110.0               4.0
#
#     transmission_type      driven_wheels number_of_doors market_category  \
# 674         automatic  front_wheel_drive             4.0     performance
# 675         automatic  front_wheel_drive             4.0     performance
# 676         automatic  front_wheel_drive             4.0     performance
# ...

# %%
df[df['market_category'].isnull()]
# Out:
#          make  model  year                engine_fuel_type  engine_hp  \
# 685     mazda    626  2000                regular_unleaded      170.0
# 686     mazda    626  2000                regular_unleaded      170.0
# 687     mazda    626  2000                regular_unleaded      130.0
# 688     mazda    626  2000                regular_unleaded      130.0
# 689     mazda    626  2001     premium_unleaded_(required)      165.0
# ...       ...    ...   ...                             ...        ...
# 11792  subaru     xt  1991                regular_unleaded       97.0
# 11793  subaru     xt  1991                regular_unleaded      145.0
# 11794  subaru     xt  1991                regular_unleaded      145.0
# 11867     gmc  yukon  2015  premium_unleaded_(recommended)      420.0
# 11868     gmc  yukon  2015  premium_unleaded_(recommended)      420.0
#
#        engine_cylinders transmission_type      driven_wheels number_of_doors  \
# ...

# %%
df[(df.make == 'mazda') & (df.driven_wheels == 'front_wheel_drive') & (df.vehicle_size == 'midsize') & (df.vehicle_style == 'sedan')]
# Out:
#        make     model  year             engine_fuel_type  engine_hp  \
# 398   mazda         3  2017             regular_unleaded      155.0
# 399   mazda         3  2017             regular_unleaded      155.0
# 400   mazda         3  2017             regular_unleaded      184.0
# 401   mazda         3  2017             regular_unleaded      184.0
# 407   mazda         3  2017             regular_unleaded      155.0
# 410   mazda         3  2017             regular_unleaded      155.0
# 685   mazda       626  2000             regular_unleaded      170.0
# 686   mazda       626  2000             regular_unleaded      170.0
# 687   mazda       626  2000             regular_unleaded      130.0
# 688   mazda       626  2000             regular_unleaded      130.0
# 689   mazda       626  2001  premium_unleaded_(required)      165.0
# 690   mazda       626  2001  premium_unleaded_(required)      165.0
# 691   mazda       626  2001             regular_unleaded      125.0
# ...

# %%
M_M = (df.make == 'mazda') & (df.driven_wheels == 'front_wheel_drive') & (df.vehicle_size == 'midsize') & (df.vehicle_style == 'sedan')
M_M
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
df.loc[M_M, 'market_category'] = df.loc[M_M, 'market_category'].fillna('performance')

# %%
df[df['market_category'].isnull()]
# Out:
#           make   model  year                engine_fuel_type  engine_hp  \
# 981      mazda     929  1993                regular_unleaded      195.0
# 982      mazda     929  1994                regular_unleaded      193.0
# 983      mazda     929  1995                regular_unleaded      193.0
# 1173   hyundai  accent  2014                regular_unleaded      138.0
# 1175   hyundai  accent  2014                regular_unleaded      138.0
# ...        ...     ...   ...                             ...        ...
# 11792   subaru      xt  1991                regular_unleaded       97.0
# 11793   subaru      xt  1991                regular_unleaded      145.0
# 11794   subaru      xt  1991                regular_unleaded      145.0
# 11867      gmc   yukon  2015  premium_unleaded_(recommended)      420.0
# 11868      gmc   yukon  2015  premium_unleaded_(recommended)      420.0
#
#        engine_cylinders transmission_type      driven_wheels number_of_doors  \
# ...

# %%
df[(df.make == 'mazda') & (df.model == '929')]
# Out:
#       make model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 981  mazda   929  1993  regular_unleaded      195.0               6.0
# 982  mazda   929  1994  regular_unleaded      193.0               6.0
# 983  mazda   929  1995  regular_unleaded      193.0               6.0
#
#     transmission_type     driven_wheels number_of_doors market_category  \
# 981         automatic  rear_wheel_drive             4.0             NaN
# 982         automatic  rear_wheel_drive             4.0             NaN
# 983         automatic  rear_wheel_drive             4.0             NaN
#
#     vehicle_size vehicle_style  highway_mpg  city_mpg  popularity  msrp  age
# 981      midsize         sedan           22        17         586  2000   25
# 982      midsize         sedan           22        17         586  2000   24
# 983      midsize         sedan           22        17         586  2000   23

# %%
df[(df.engine_fuel_type == 'regular_unleaded')& (df.transmission_type == 'automatic') & (df.engine_cylinders == 6.0) & (df.driven_wheels == 'rear_wheel_drive') & (df.vehicle_size == 'midsize') & (df.vehicle_style == 'sedan')]
# Out:
#                make      model  year  engine_fuel_type  engine_hp  \
# 167   mercedes-benz  300-class  1991  regular_unleaded      158.0
# 170   mercedes-benz  300-class  1991  regular_unleaded      177.0
# 181   mercedes-benz  300-class  1992  regular_unleaded      177.0
# 184   mercedes-benz  300-class  1992  regular_unleaded      158.0
# 189   mercedes-benz  300-class  1993  regular_unleaded      217.0
# 192   mercedes-benz  300-class  1993  regular_unleaded      194.0
# 754           volvo        760  1990  regular_unleaded      144.0
# 981           mazda        929  1993  regular_unleaded      195.0
# 982           mazda        929  1994  regular_unleaded      193.0
# 983           mazda        929  1995  regular_unleaded      193.0
# 1003          volvo        960  1995  regular_unleaded      181.0
# 1004          volvo        960  1996  regular_unleaded      181.0
# 1007          volvo        960  1997  regular_unleaded      181.0
# ...

# %%
M_929 = (df.make == 'mazda') & (df.model == '929')
M_929
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
df.loc[M_929, 'market_category'] = df.loc[M_929, 'market_category'].fillna('luxury')

# %%
df[df['market_category'].isnull()]
# Out:
#           make   model  year                engine_fuel_type  engine_hp  \
# 1173   hyundai  accent  2014                regular_unleaded      138.0
# 1175   hyundai  accent  2014                regular_unleaded      138.0
# 1177   hyundai  accent  2015                regular_unleaded      137.0
# 1179   hyundai  accent  2015                regular_unleaded      137.0
# 1183   hyundai  accent  2016                regular_unleaded      137.0
# ...        ...     ...   ...                             ...        ...
# 11792   subaru      xt  1991                regular_unleaded       97.0
# 11793   subaru      xt  1991                regular_unleaded      145.0
# 11794   subaru      xt  1991                regular_unleaded      145.0
# 11867      gmc   yukon  2015  premium_unleaded_(recommended)      420.0
# 11868      gmc   yukon  2015  premium_unleaded_(recommended)      420.0
#
#        engine_cylinders transmission_type      driven_wheels number_of_doors  \
# ...

# %%
df[(df.make == 'hyundai') & (df.vehicle_size == 'compact') & (df.vehicle_style == 'sedan')]
# Out:
#          make    model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 1173  hyundai   accent  2014  regular_unleaded      138.0               4.0
# 1175  hyundai   accent  2014  regular_unleaded      138.0               4.0
# 1177  hyundai   accent  2015  regular_unleaded      137.0               4.0
# 1179  hyundai   accent  2015  regular_unleaded      137.0               4.0
# 1183  hyundai   accent  2016  regular_unleaded      137.0               4.0
# 1187  hyundai   accent  2016  regular_unleaded      137.0               4.0
# 3856  hyundai  elantra  2015  regular_unleaded      173.0               4.0
# 3857  hyundai  elantra  2015  regular_unleaded      145.0               4.0
# 3858  hyundai  elantra  2015  regular_unleaded      145.0               4.0
# 3859  hyundai  elantra  2015  regular_unleaded      145.0               4.0
# 3860  hyundai  elantra  2015  regular_unleaded      166.0               4.0
# ...

# %%
H = (df.make == 'hyundai') & (df.vehicle_size == 'compact') & (df.vehicle_style == 'sedan')
H
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
df.loc[H, 'market_category'] = df.loc[H, 'market_category'].fillna('performance')

# %%
df[df['market_category'].isnull()]
# Out:
#            make    model  year                engine_fuel_type  engine_hp  \
# 1189   plymouth  acclaim  1993                regular_unleaded      100.0
# 1190   plymouth  acclaim  1994                regular_unleaded      106.0
# 1191   plymouth  acclaim  1995                regular_unleaded      100.0
# 1213      honda   accord  2015                regular_unleaded      278.0
# 1217      honda   accord  2015                regular_unleaded      185.0
# ...         ...      ...   ...                             ...        ...
# 11792    subaru       xt  1991                regular_unleaded       97.0
# 11793    subaru       xt  1991                regular_unleaded      145.0
# 11794    subaru       xt  1991                regular_unleaded      145.0
# 11867       gmc    yukon  2015  premium_unleaded_(recommended)      420.0
# 11868       gmc    yukon  2015  premium_unleaded_(recommended)      420.0
#
#        engine_cylinders transmission_type      driven_wheels number_of_doors  \
# ...

# %%
df[(df.make == 'plymouth') & (df.engine_fuel_type == 'regular_unleaded')  &(df.vehicle_size == 'compact') & (df.vehicle_style == 'sedan')]
# Out:
#           make    model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 1189  plymouth  acclaim  1993  regular_unleaded      100.0               4.0
# 1190  plymouth  acclaim  1994  regular_unleaded      106.0               4.0
# 1191  plymouth  acclaim  1995  regular_unleaded      100.0               4.0
# 2829  plymouth     colt  1993  regular_unleaded      113.0               4.0
# 2830  plymouth     colt  1993  regular_unleaded       92.0               4.0
# 2838  plymouth     colt  1994  regular_unleaded      113.0               4.0
# 2839  plymouth     colt  1994  regular_unleaded      113.0               4.0
# 7182  plymouth     neon  1999  regular_unleaded      132.0               4.0
# 7184  plymouth     neon  1999  regular_unleaded      132.0               4.0
# 7185  plymouth     neon  1999  regular_unleaded      150.0               4.0
# 7186  plymouth     neon  2000  regular_unleaded      132.0               4.0
# ...

# %%
df[(df.engine_fuel_type == 'regular_unleaded')& (df.engine_cylinders == 4.0) & (df.driven_wheels == 'front_wheel_drive') &(df.vehicle_size == 'compact') & (df.vehicle_style == 'sedan')]
# Out:
#          make     model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 358     mazda         3  2015  regular_unleaded      184.0               4.0
# 359     mazda         3  2015  regular_unleaded      184.0               4.0
# 360     mazda         3  2015  regular_unleaded      155.0               4.0
# 361     mazda         3  2015  regular_unleaded      155.0               4.0
# 362     mazda         3  2015  regular_unleaded      155.0               4.0
# ...       ...       ...   ...               ...        ...               ...
# 11359  nissan     versa  2017  regular_unleaded      109.0               4.0
# 11360  nissan     versa  2017  regular_unleaded      109.0               4.0
# 11361  nissan     versa  2017  regular_unleaded      109.0               4.0
# 11809  toyota  yaris_ia  2017  regular_unleaded      106.0               4.0
# 11810  toyota  yaris_ia  2017  regular_unleaded      106.0               4.0
#
# ...

# %%
r = df[(df.engine_fuel_type == 'regular_unleaded')& (df.engine_cylinders == 4.0) & (df.driven_wheels == 'front_wheel_drive') &(df.vehicle_size == 'compact') & (df.vehicle_style == 'sedan')]

# %%
r['market_category'].unique()
# Out:
# array(['performance', 'hatchback', 'luxury', nan, 'hybrid',
#        'luxury,performance'], dtype=object)

# %%
NA_0 = (df.make == 'plymouth') & (df.engine_fuel_type == 'regular_unleaded')  &(df.vehicle_size == 'compact') & (df.vehicle_style == 'sedan')
NA_0
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
df.loc[NA_0, 'market_category'] = df.loc[NA_0, 'market_category'].fillna(0)

# %%
df[df['market_category'].isnull()]
# Out:
#          make   model  year                engine_fuel_type  engine_hp  \
# 1213    honda  accord  2015                regular_unleaded      278.0
# 1217    honda  accord  2015                regular_unleaded      185.0
# 1220    honda  accord  2015                regular_unleaded      189.0
# 1221    honda  accord  2015                regular_unleaded      185.0
# 1223    honda  accord  2015                regular_unleaded      185.0
# ...       ...     ...   ...                             ...        ...
# 11792  subaru      xt  1991                regular_unleaded       97.0
# 11793  subaru      xt  1991                regular_unleaded      145.0
# 11794  subaru      xt  1991                regular_unleaded      145.0
# 11867     gmc   yukon  2015  premium_unleaded_(recommended)      420.0
# 11868     gmc   yukon  2015  premium_unleaded_(recommended)      420.0
#
#        engine_cylinders transmission_type      driven_wheels number_of_doors  \
# ...

# %%
d = df[(df.make == 'honda') & (df.model == 'accord')]

# %%
d['market_category'].unique()
# Out:
# array(['performance', nan, 'luxury'], dtype=object)

# %%
H_A = (df.make == 'honda') & (df.model == 'accord')
H_A
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
df.loc[H_A, 'market_category'] = df.loc[H_A, 'market_category'].fillna('performance,luxury')

# %%
df[(df['market_category'].isnull())]
# Out:
#              make    model  year                engine_fuel_type  engine_hp  \
# 1287   oldsmobile  achieva  1996                regular_unleaded      150.0
# 1290   oldsmobile  achieva  1997                regular_unleaded      150.0
# 1291   oldsmobile  achieva  1998                regular_unleaded      150.0
# 1300       suzuki    aerio  2005                regular_unleaded      155.0
# 1301       suzuki    aerio  2005                regular_unleaded      155.0
# ...           ...      ...   ...                             ...        ...
# 11792      subaru       xt  1991                regular_unleaded       97.0
# 11793      subaru       xt  1991                regular_unleaded      145.0
# 11794      subaru       xt  1991                regular_unleaded      145.0
# 11867         gmc    yukon  2015  premium_unleaded_(recommended)      420.0
# 11868         gmc    yukon  2015  premium_unleaded_(recommended)      420.0
#
# ...

# %%
df[(df.make == 'oldsmobile') & (df.model == 'achieva')]
# Out:
#             make    model  year  engine_fuel_type  engine_hp  \
# 1287  oldsmobile  achieva  1996  regular_unleaded      150.0
# 1288  oldsmobile  achieva  1996  regular_unleaded      150.0
# 1289  oldsmobile  achieva  1997  regular_unleaded      150.0
# 1290  oldsmobile  achieva  1997  regular_unleaded      150.0
# 1291  oldsmobile  achieva  1998  regular_unleaded      150.0
#
#       engine_cylinders transmission_type      driven_wheels number_of_doors  \
# 1287               4.0            manual  front_wheel_drive             4.0
# 1288               4.0            manual  front_wheel_drive             2.0
# 1289               4.0           unknown  front_wheel_drive             2.0
# 1290               4.0           unknown  front_wheel_drive             4.0
# 1291               6.0         automatic  front_wheel_drive             4.0
#
#      market_category vehicle_size vehicle_style  highway_mpg  city_mpg  \
# ...

# %%
O_A = (df.make == 'oldsmobile') & (df.model == 'achieva')
O_A
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
df.loc[O_A, 'market_category'] = df.loc[O_A, 'market_category'].fillna('luxury')

# %%
df[(df['market_category'].isnull())]
# Out:
#          make  model  year                engine_fuel_type  engine_hp  \
# 1300   suzuki  aerio  2005                regular_unleaded      155.0
# 1301   suzuki  aerio  2005                regular_unleaded      155.0
# 1302   suzuki  aerio  2005                regular_unleaded      155.0
# 1303   suzuki  aerio  2005                regular_unleaded      155.0
# 1304   suzuki  aerio  2005                regular_unleaded      155.0
# ...       ...    ...   ...                             ...        ...
# 11792  subaru     xt  1991                regular_unleaded       97.0
# 11793  subaru     xt  1991                regular_unleaded      145.0
# 11794  subaru     xt  1991                regular_unleaded      145.0
# 11867     gmc  yukon  2015  premium_unleaded_(recommended)      420.0
# 11868     gmc  yukon  2015  premium_unleaded_(recommended)      420.0
#
#        engine_cylinders transmission_type      driven_wheels number_of_doors  \
# ...

# %%
ttt = df[(df.make == 'suzuki') & (df.engine_fuel_type == 'regular_unleaded') & (df.vehicle_size == 'compact') & (df['market_category'].isnull())]
ttt
# Out:
#          make  model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 1300   suzuki  aerio  2005  regular_unleaded      155.0               4.0
# 1301   suzuki  aerio  2005  regular_unleaded      155.0               4.0
# 1302   suzuki  aerio  2005  regular_unleaded      155.0               4.0
# 1303   suzuki  aerio  2005  regular_unleaded      155.0               4.0
# 1304   suzuki  aerio  2005  regular_unleaded      155.0               4.0
# ...       ...    ...   ...               ...        ...               ...
# 11478  suzuki   x-90  1997  regular_unleaded       95.0               4.0
# 11479  suzuki   x-90  1997  regular_unleaded       95.0               4.0
# 11480  suzuki   x-90  1998  regular_unleaded       95.0               4.0
# 11481  suzuki   x-90  1998  regular_unleaded       95.0               4.0
# 11482  suzuki   x-90  1998  regular_unleaded       95.0               4.0
#
#       transmission_type      driven_wheels number_of_doors market_category  \
# ...

# %%
ttt['market_category'].unique()
# Out:
# array([nan], dtype=object)

# %%
ttt = df[(df.vehicle_style == 'wagon') & (df.engine_fuel_type == 'regular_unleaded') & (df.vehicle_size == 'compact') & (df['market_category'].notnull())]

# %%
ttt['market_category'].unique()
# Out:
# array(['luxury,performance', 'luxury', 'hybrid', 'crossover'],
#       dtype=object)

# %%
tt = df[(df.make == 'suzuki') & (df.vehicle_style == 'sedan')]

# %%
tt['market_category'].unique()
# Out:
# array([nan], dtype=object)

# %%
S_S = (df.make == 'suzuki') & (df.vehicle_style == 'sedan')

# %%
df.loc[S_S, 'market_category'] = df.loc[S_S, 'market_category'].fillna(0)

# %%
df[(df['market_category'].isnull())]
# Out:
#          make  model  year                engine_fuel_type  engine_hp  \
# 1301   suzuki  aerio  2005                regular_unleaded      155.0
# 1302   suzuki  aerio  2005                regular_unleaded      155.0
# 1304   suzuki  aerio  2005                regular_unleaded      155.0
# 1305   suzuki  aerio  2005                regular_unleaded      155.0
# 1307   suzuki  aerio  2005                regular_unleaded      155.0
# ...       ...    ...   ...                             ...        ...
# 11792  subaru     xt  1991                regular_unleaded       97.0
# 11793  subaru     xt  1991                regular_unleaded      145.0
# 11794  subaru     xt  1991                regular_unleaded      145.0
# 11867     gmc  yukon  2015  premium_unleaded_(recommended)      420.0
# 11868     gmc  yukon  2015  premium_unleaded_(recommended)      420.0
#
#        engine_cylinders transmission_type      driven_wheels number_of_doors  \
# ...

# %%
df[(df.make == 'suzuki') & (df.vehicle_style == 'wagon')]
# Out:
#         make    model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 1301  suzuki    aerio  2005  regular_unleaded      155.0               4.0
# 1302  suzuki    aerio  2005  regular_unleaded      155.0               4.0
# 1304  suzuki    aerio  2005  regular_unleaded      155.0               4.0
# 1305  suzuki    aerio  2005  regular_unleaded      155.0               4.0
# 1307  suzuki    aerio  2005  regular_unleaded      155.0               4.0
# 1311  suzuki    aerio  2005  regular_unleaded      155.0               4.0
# 1314  suzuki    aerio  2006  regular_unleaded      155.0               4.0
# 1315  suzuki    aerio  2006  regular_unleaded      155.0               4.0
# 1319  suzuki    aerio  2006  regular_unleaded      155.0               4.0
# 1320  suzuki    aerio  2006  regular_unleaded      155.0               4.0
# 1322  suzuki    aerio  2006  regular_unleaded      155.0               4.0
# ...

# %%
ty = df[(df.vehicle_style == 'wagon') & (df.engine_cylinders == 4.0) & (df.vehicle_size == 'compact') & (df.engine_fuel_type == 'regular_unleaded') & (df.number_of_doors == 4.0) & (df.driven_wheels == 'front_wheel_drive')]

# %%
ty['market_category'].unique()
# Out:
# array([nan, 'hybrid'], dtype=object)

# %%
ty = (df.vehicle_style == 'wagon') & (df.engine_cylinders == 4.0) & (df.vehicle_size == 'compact') & (df.engine_fuel_type == 'regular_unleaded') & (df.number_of_doors == 4.0) & (df.driven_wheels == 'front_wheel_drive')

# %%
df.loc[ty, 'market_category'] = df.loc[ty, 'market_category'].fillna(0)

# %%
ty_1 = df[(df.vehicle_style == 'wagon') & (df.engine_cylinders == 4.0) & (df.vehicle_size == 'compact') & (df.engine_fuel_type == 'regular_unleaded') & (df.number_of_doors == 4.0) & (df.driven_wheels == 'all_wheel_drive')]
ty_1
# Out:
#             make          model  year  engine_fuel_type  engine_hp  \
# 801         saab           9-2x  2005  regular_unleaded      165.0
# 803         saab           9-2x  2006  regular_unleaded      173.0
# 1305      suzuki          aerio  2005  regular_unleaded      155.0
# 1311      suzuki          aerio  2005  regular_unleaded      155.0
# 1314      suzuki          aerio  2006  regular_unleaded      155.0
# 1322      suzuki          aerio  2006  regular_unleaded      155.0
# 2825    plymouth           colt  1992  regular_unleaded      113.0
# 2828    plymouth           colt  1993  regular_unleaded      113.0
# 2835    plymouth           colt  1994  regular_unleaded      136.0
# 5359  volkswagen  golf_alltrack  2017  regular_unleaded      170.0
# 5360  volkswagen  golf_alltrack  2017  regular_unleaded      170.0
# 5361  volkswagen  golf_alltrack  2017  regular_unleaded      170.0
# 5362  volkswagen  golf_alltrack  2017  regular_unleaded      170.0
# ...

# %%
ty_1 = (df.vehicle_style == 'wagon') & (df.engine_cylinders == 4.0) & (df.vehicle_size == 'compact') & (df.engine_fuel_type == 'regular_unleaded') & (df.number_of_doors == 4.0) & (df.driven_wheels == 'all_wheel_drive')
ty_1
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
df.loc[ty_1, 'market_category'] = df.loc[ty_1, 'market_category'].fillna(0)

# %%
df[(df['market_category'].isnull())]
# Out:
#          make     model  year                engine_fuel_type  engine_hp  \
# 1331     ford  aerostar  1995                regular_unleaded      135.0
# 1332     ford  aerostar  1995                regular_unleaded      135.0
# 1333     ford  aerostar  1995                regular_unleaded      155.0
# 1334     ford  aerostar  1995                regular_unleaded      135.0
# 1335     ford  aerostar  1996                regular_unleaded      140.0
# ...       ...       ...   ...                             ...        ...
# 11792  subaru        xt  1991                regular_unleaded       97.0
# 11793  subaru        xt  1991                regular_unleaded      145.0
# 11794  subaru        xt  1991                regular_unleaded      145.0
# 11867     gmc     yukon  2015  premium_unleaded_(recommended)      420.0
# 11868     gmc     yukon  2015  premium_unleaded_(recommended)      420.0
#
#        engine_cylinders transmission_type      driven_wheels number_of_doors  \
# ...

# %%
df[(df.make == 'ford')]
# Out:
#        make     model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 1331   ford  aerostar  1995  regular_unleaded      135.0               6.0
# 1332   ford  aerostar  1995  regular_unleaded      135.0               6.0
# 1333   ford  aerostar  1995  regular_unleaded      155.0               6.0
# 1334   ford  aerostar  1995  regular_unleaded      135.0               6.0
# 1335   ford  aerostar  1996  regular_unleaded      140.0               6.0
# ...     ...       ...   ...               ...        ...               ...
# 11443  ford  windstar  2003  regular_unleaded      200.0               6.0
# 11444  ford  windstar  2003  regular_unleaded      200.0               6.0
# 11445  ford  windstar  2003  regular_unleaded      200.0               6.0
# 11446  ford  windstar  2003  regular_unleaded      200.0               6.0
# 11447  ford  windstar  2003  regular_unleaded      200.0               6.0
#
# ...

# %%
df[(df.vehicle_style == 'passenger_minivan')& (df.engine_fuel_type == 'regular_unleaded') &(df.vehicle_size == 'midsize') & (df['market_category'].notnull())]
# Out:
#             make     model  year  engine_fuel_type  engine_hp  \
# 7410    chrysler  pacifica  2017  regular_unleaded      287.0
# 10374      buick   terraza  2007  regular_unleaded      240.0
# 10375      buick   terraza  2007  regular_unleaded      240.0
# 10376      buick   terraza  2007  regular_unleaded      240.0
# 11080  chevrolet  uplander  2007  regular_unleaded      240.0
# 11081  chevrolet  uplander  2007  regular_unleaded      240.0
# 11082  chevrolet  uplander  2007  regular_unleaded      240.0
# 11083  chevrolet  uplander  2007  regular_unleaded      240.0
# 11084  chevrolet  uplander  2007  regular_unleaded      240.0
# 11088  chevrolet  uplander  2008  regular_unleaded      240.0
# 11090  chevrolet  uplander  2008  regular_unleaded      240.0
# 11091  chevrolet  uplander  2008  regular_unleaded      240.0
# 11416   chrysler   voyager  2002  regular_unleaded      150.0
#
#        engine_cylinders transmission_type      driven_wheels number_of_doors  \
# ...

# %%
df[(df.vehicle_style == 'cargo_minivan')& (df.engine_fuel_type == 'regular_unleaded') &(df.vehicle_size == 'midsize') & (df['market_category'].notnull())]
# Out:
#             make     model  year  engine_fuel_type  engine_hp  \
# 11079  chevrolet  uplander  2007  regular_unleaded      240.0
# 11089  chevrolet  uplander  2008  regular_unleaded      240.0
#
#        engine_cylinders transmission_type      driven_wheels number_of_doors  \
# 11079               6.0         automatic  front_wheel_drive             4.0
# 11089               6.0         automatic  front_wheel_drive             4.0
#
#       market_category vehicle_size  vehicle_style  highway_mpg  city_mpg  \
# 11079       flex_fuel      midsize  cargo_minivan           23        16
# 11089       flex_fuel      midsize  cargo_minivan           23        16
#
#        popularity   msrp  age
# 11079        1385  22105   11
# 11089        1385  23080   10

# %%
df[(df.vehicle_style == 'passenger_minivan')& (df.engine_fuel_type == 'regular_unleaded') &(df.vehicle_size == 'midsize') & (df['market_category'].isnull())]
# Out:
#           make      model  year  engine_fuel_type  engine_hp  \
# 1332      ford   aerostar  1995  regular_unleaded      135.0
# 1335      ford   aerostar  1996  regular_unleaded      140.0
# 1342      ford   aerostar  1997  regular_unleaded      140.0
# 3973   hyundai  entourage  2007  regular_unleaded      242.0
# 3974   hyundai  entourage  2007  regular_unleaded      242.0
# ...        ...        ...   ...               ...        ...
# 11443     ford   windstar  2003  regular_unleaded      200.0
# 11444     ford   windstar  2003  regular_unleaded      200.0
# 11445     ford   windstar  2003  regular_unleaded      200.0
# 11446     ford   windstar  2003  regular_unleaded      200.0
# 11447     ford   windstar  2003  regular_unleaded      200.0
#
#        engine_cylinders transmission_type      driven_wheels number_of_doors  \
# 1332                6.0         automatic   rear_wheel_drive             3.0
# ...

# %%
Pass_van = (df.vehicle_style == 'passenger_minivan')& (df.engine_fuel_type == 'regular_unleaded') &(df.vehicle_size == 'midsize') & (df['market_category'].isnull())
Pass_van
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
df.loc[Pass_van, 'market_category'] = df.loc[Pass_van, 'market_category'].fillna('flex_fuel')

# %%
cargo_van = (df.vehicle_style == 'cargo_minivan')& (df.engine_fuel_type == 'regular_unleaded') &(df.vehicle_size == 'midsize') & (df['market_category'].isnull())
cargo_van
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
df.loc[cargo_van, 'market_category'] = df.loc[cargo_van, 'market_category'].fillna('flex_fuel')

# %%
df[df['market_category'].isnull()]
# Out:
#          make     model  year                engine_fuel_type  engine_hp  \
# 1333     ford  aerostar  1995                regular_unleaded      155.0
# 1334     ford  aerostar  1995                regular_unleaded      135.0
# 1336     ford  aerostar  1996                regular_unleaded      155.0
# 1337     ford  aerostar  1996                regular_unleaded      140.0
# 1340     ford  aerostar  1997                regular_unleaded      140.0
# ...       ...       ...   ...                             ...        ...
# 11792  subaru        xt  1991                regular_unleaded       97.0
# 11793  subaru        xt  1991                regular_unleaded      145.0
# 11794  subaru        xt  1991                regular_unleaded      145.0
# 11867     gmc     yukon  2015  premium_unleaded_(recommended)      420.0
# 11868     gmc     yukon  2015  premium_unleaded_(recommended)      420.0
#
#        engine_cylinders transmission_type      driven_wheels number_of_doors  \
# ...

# %%
df[(df.vehicle_style == 'passenger_minivan')& (df.vehicle_size == 'large') &(df.driven_wheels == 'all_wheel_drive') & (df['market_category'].notnull())]
# Out:
# Empty DataFrame
# Columns: [make, model, year, engine_fuel_type, engine_hp, engine_cylinders, transmission_type, driven_wheels, number_of_doors, market_category, vehicle_size, vehicle_style, highway_mpg, city_mpg, popularity, msrp, age]
# Index: []

# %%
pass_large = (df.vehicle_style == 'passenger_minivan')& (df.engine_fuel_type == 'regular_unleaded') &(df.vehicle_size == 'large') & (df['market_category'].isnull())
pass_large
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
df.loc[pass_large, 'market_category'] = df.loc[pass_large, 'market_category'].fillna('flex_fuel')

# %%
df['market_category'].replace('flex_fuel\t', 'flex_fuel', inplace = True)

# %%
df[df['market_category'].isnull()]
# Out:
#              make  model  year                engine_fuel_type  engine_hp  \
# 1343   oldsmobile  alero  2002                regular_unleaded      170.0
# 1344   oldsmobile  alero  2002                regular_unleaded      170.0
# 1345   oldsmobile  alero  2002                regular_unleaded      140.0
# 1346   oldsmobile  alero  2002                regular_unleaded      170.0
# 1347   oldsmobile  alero  2002                regular_unleaded      140.0
# ...           ...    ...   ...                             ...        ...
# 11792      subaru     xt  1991                regular_unleaded       97.0
# 11793      subaru     xt  1991                regular_unleaded      145.0
# 11794      subaru     xt  1991                regular_unleaded      145.0
# 11867         gmc  yukon  2015  premium_unleaded_(recommended)      420.0
# 11868         gmc  yukon  2015  premium_unleaded_(recommended)      420.0
#
#        engine_cylinders transmission_type      driven_wheels number_of_doors  \
# ...

# %%
df[(df.vehicle_style == 'coupe') & (df.vehicle_size == 'midsize') &(df.driven_wheels == 'front_wheel_drive') & (df['market_category'].notnull())]
# Out:
#         make    model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 1212   honda   accord  2015  regular_unleaded      278.0               6.0
# 1214   honda   accord  2015  regular_unleaded      278.0               6.0
# 1215   honda   accord  2015  regular_unleaded      185.0               4.0
# 1216   honda   accord  2015  regular_unleaded      185.0               4.0
# 1218   honda   accord  2015  regular_unleaded      185.0               4.0
# ...      ...      ...   ...               ...        ...               ...
# 10007  dodge  stratus  2004  regular_unleaded      200.0               6.0
# 10012  dodge  stratus  2004  regular_unleaded      147.0               4.0
# 10013  dodge  stratus  2004  regular_unleaded      142.0               4.0
# 10016  dodge  stratus  2005  regular_unleaded      200.0               6.0
# 10018  dodge  stratus  2005  regular_unleaded      147.0               4.0
#
# ...

# %%
df[(df.make == 'oldsmobile') & (df.model == 'alero') & (df['market_category'].notnull())]
# Out:
#             make  model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 1348  oldsmobile  alero  2002  regular_unleaded      140.0               4.0
# 1349  oldsmobile  alero  2002  regular_unleaded      140.0               4.0
# 1352  oldsmobile  alero  2003  regular_unleaded      140.0               4.0
# 1358  oldsmobile  alero  2003  regular_unleaded      140.0               4.0
# 1362  oldsmobile  alero  2004  regular_unleaded      140.0               4.0
# 1363  oldsmobile  alero  2004  regular_unleaded      140.0               4.0
#
#      transmission_type      driven_wheels number_of_doors market_category  \
# 1348         automatic  front_wheel_drive             2.0          luxury
# 1349         automatic  front_wheel_drive             2.0          luxury
# 1352         automatic  front_wheel_drive             2.0          luxury
# 1358         automatic  front_wheel_drive             2.0          luxury
# ...

# %%
df[(df.make == 'oldsmobile') & (df.model == 'alero') & (df.vehicle_style == 'coupe') & (df['market_category'].isnull())]
# Out:
#             make  model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 1343  oldsmobile  alero  2002  regular_unleaded      170.0               6.0
# 1344  oldsmobile  alero  2002  regular_unleaded      170.0               6.0
# 1353  oldsmobile  alero  2003  regular_unleaded      170.0               6.0
# 1355  oldsmobile  alero  2003  regular_unleaded      170.0               6.0
# 1359  oldsmobile  alero  2004  regular_unleaded      170.0               6.0
# 1366  oldsmobile  alero  2004  regular_unleaded      170.0               6.0
#
#      transmission_type      driven_wheels number_of_doors market_category  \
# 1343         automatic  front_wheel_drive             2.0             NaN
# 1344         automatic  front_wheel_drive             2.0             NaN
# 1353         automatic  front_wheel_drive             2.0             NaN
# 1355         automatic  front_wheel_drive             2.0             NaN
# ...

# %%
old_alero = (df.make == 'oldsmobile') & (df.model == 'alero') & (df.vehicle_style == 'coupe') & (df['market_category'].isnull())
old_alero
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
df.loc[old_alero, 'market_category'] = df.loc[old_alero, 'market_category'].fillna('luxury')

# %%
df[df['market_category'].isnull()]
# Out:
#              make  model  year                engine_fuel_type  engine_hp  \
# 1345   oldsmobile  alero  2002                regular_unleaded      140.0
# 1346   oldsmobile  alero  2002                regular_unleaded      170.0
# 1347   oldsmobile  alero  2002                regular_unleaded      140.0
# 1350   oldsmobile  alero  2002                regular_unleaded      170.0
# 1351   oldsmobile  alero  2003                regular_unleaded      170.0
# ...           ...    ...   ...                             ...        ...
# 11792      subaru     xt  1991                regular_unleaded       97.0
# 11793      subaru     xt  1991                regular_unleaded      145.0
# 11794      subaru     xt  1991                regular_unleaded      145.0
# 11867         gmc  yukon  2015  premium_unleaded_(recommended)      420.0
# 11868         gmc  yukon  2015  premium_unleaded_(recommended)      420.0
#
#        engine_cylinders transmission_type      driven_wheels number_of_doors  \
# ...

# %%
qwe = df[(df.vehicle_size == 'midsize') & (df.engine_fuel_type == 'regular_unleaded') & (df.vehicle_style == 'sedan') & (df['market_category'].notnull())]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   make               11914 non-null  object
#  1   model              11914 non-null  object
#  2   year               11914 non-null  int64
#  3   engine_fuel_type   11914 non-null  object
#  4   engine_hp          11914 non-null  float64
#  5   engine_cylinders   11914 non-null  float64
#  6   transmission_type  11914 non-null  object
#  7   driven_wheels      11914 non-null  object
#  8   number_of_doors    11914 non-null  object
#  9   market_category    9277 non-null   object
#  10  vehicle_size       11914 non-null  object
#  11  vehicle_style      11914 non-null  object
#  12  highway_mpg        11914 non-null  int64
#  13  city_mpg           11914 non-null  int64
#  14  popularity         11914 non-null  int64
#  15  msrp               11914 non-null  int64
# ...

# %%
df['market_category'] = df['market_category'].fillna(0)

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score 
from sklearn.metrics import mean_squared_error

import matplotlib.pyplot as plt

# %%
model = LinearRegression()

# %%
dummies = pd.get_dummies(df)
# Out:
# C:\Users\Lakshmeesh s reddy\anaconda3\lib\site-packages\pandas\core\algorithms.py:798: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   uniques = Index(uniques)

# %%
dummies
# Out:
#        year  engine_hp  engine_cylinders  highway_mpg  city_mpg  popularity  \
# 0      2011      335.0               6.0           26        19        3916
# 1      2011      300.0               6.0           28        19        3916
# 2      2011      300.0               6.0           28        20        3916
# 3      2011      230.0               6.0           28        18        3916
# 4      2011      230.0               6.0           28        18        3916
# ...     ...        ...               ...          ...       ...         ...
# 11909  2012      300.0               6.0           23        16         204
# 11910  2012      300.0               6.0           23        16         204
# 11911  2012      300.0               6.0           23        16         204
# 11912  2013      300.0               6.0           23        16         204
# 11913  2006      221.0               6.0           26        17          61
#
#         msrp  age  make_acura  make_alfa_romeo  ...  \
# ...

# %%
X = dummies.drop('msrp', axis = 'columns')

# %%
y = dummies['msrp']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 2.868326688505246e+17

# %%
model.coef_
# Out:
# array([-2.93711360e+17,  1.12800000e+05,  2.43200000e+03, ...,
#        -8.68309922e+14, -8.66454467e+14, -8.66454467e+14])

# %%
model.predict(X_train)
# Out:
# array([36256.,  7552., 37152., ..., 38976., 33376., 72576.])

# %%
model.fit(X_test, y_test)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 7.029869770044924e+17

# %%
model.coef_
# Out:
# array([-7.06724675e+17,  1.00992000e+05,  6.52800000e+03, ...,
#        -2.28328460e+15,  1.02865372e+15,  1.02865372e+15])

# %%
model.coef_
# Out:
# array([-7.06724675e+17,  1.00992000e+05,  6.52800000e+03, ...,
#        -2.28328460e+15,  1.02865372e+15,  1.02865372e+15])

# %%
model.score(X_test, y_test)
# Out:
# 0.9889808637398257
